// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.18"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.18"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2D chart can be created using the `Chart.Histogram2D` or `Chart.Histogram2DContour` functions.

// %%
let histogramContour = Chart.Histogram2DContour (x,y,ContourLine=Line.init(Width=0.))

// %%
histogramContour
// Out:
// <div id="c44d09a3-8165-4d0b-87c3-dc81196e4a11"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_c44d09a381654d0b87c3dc81196e4a11 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.6.3.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.8697851333888902,-1.7180132319540586,-1.1788754246615953,-0.15726516802857593,-1.171490150302773,-1.1968177077488031,-1.6429421124090635,-0.619626073247888,-0.7206497850799078,-0.8875578939397573,-1.255420173360107,-1.1174900046530878,-2.0413442754767557,-0.9773258145450778,-0.9586234701959409,0.3335157104462232,-1.3762814905356417,0.009717656192384627,-2.1766118283572964,-1.1433521206999788,-0.5234037250715642,-0.8798007994252267,-1.3043132166231919,-1.3415794838563266,-0.6361743977274652,-1.368950988678392,-0.32487345007435353,-1.6363441968076158,-0.8012110562868059,-1.6529810477712696,-1.3099512422483723,-0.9211838051656491,-1.8024038962479398,0.08320531777702977,-0.8693646093488165,-2.8138154998068354,-0.699781864963485,-0.055516151289725535,-0.570672058489542,-1.7065582470384555,-1.1034157033079135,-0.6016510803021744,-0.624654479714969,-0.9821198843001128,-0.7879243978379696,-0.7891581973512694,-0.398035761837372,0.3151311396111637,-0.2217977897562987,0.15818214962030752,-0.9392512472547202,-1.1995530362217297,-1.043