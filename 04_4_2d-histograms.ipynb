// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.14"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.14"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2D chart can be created using the `Chart.Histogram2D` or `Chart.Histogram2DContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2DContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="fdd35415-75ad-419e-a2ee-5c4e67fe7dca"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_fdd3541575ad419ea2ee5c4e67fe7dca = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2Dcontour","x":[-0.9458219463220365,-1.5394827479648354,-0.7134254922980588,-0.46565816372369995,-1.4881431873683408,-0.9361183378649792,-0.8614044263766687,-1.1777599564312684,-0.22068042694410128,-1.4209167719671063,-0.875808182771128,-0.11198868678387153,-1.338273997816878,-0.7846981662737421,-1.397651957116258,-2.5842869224256955,-0.3587067687904355,-1.0423967265201768,-1.0395827459901068,-0.5448235494051019,-0.4736902662656261,-1.0775993446603187,-1.3776134707282508,-1.5110478498780981,-1.7852470429752423,-0.6969916600354421,-0.6112637504150611,-1.5414746410627111,0.6124910011468554,-0.978530494903154,-0.6148612299317675,-0.329094191810576,-1.1433413014599132,-1.2215328093480058,-1.767104161730132,-0.45067992272178864,-1.45321016682079,-1.9795529570884014,-0.7431178854934254,-1.818478531623882,-0.531888679840933,-0.19546612429870946,-1.8266917529859845,-0.48423815502225237,-0.4816802142463085,-0.8476867825527191,-1.636433113723312,-0.7537026693739102,-0.9372275855350161,-1.1482945560