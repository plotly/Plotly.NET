// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.9"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.9"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="090765be-a684-4c1c-bed0-8d8fb7c889b1" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_090765bea6844c1cbed08d8fb7c889b1 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.6950568827926984,-1.5495135250047412,-0.19902741579826388,-1.9906353896232334,0.47680580768530323,-0.6621580553754336,-0.3719515529639881,-1.1209996091719814,-0.6101207924751433,-0.5326754080792128,-1.8036656807688374,-0.7644959603156443,-1.4852703576921722,-0.5498461075661142,-0.013278024987963377,-1.8968375705458245,-0.9065751689588126,-1.2590438059020297,-1.471426775835742,-0.9342736637178735,-1.4387704424778494,-0.44553986055113026,-0.6611448450490962,-1.9313417895779719,0.20863075061567715,-1.0557865840462277,-1.0802047661838783,-1.2899841321627197,-0.2754509100560376,-0.547065140315689,-0.5238499652478994,-1.4055407085710634,0.48802584383470715,-0.8004553369495617,-1.6408904539360558,-0.43059138306768985,-0.7536178210150515,0.07615029251323213,-0.8294826153435076,-0.21291571165657974,-1.4245639856122627,-0.7765647071362203,0.12593781706738005,0.3215975512116549,-0.040465674594099776,-1.27265595625623,-0.5217426123766535,-1.5490446520360257,-0.867444883702168,0.21078683737664772,-1.573581396845754,-0.2887641468862011,-0.5356465545203979,-0.6970721549421751,-0.9244037059189305,-1.408056591459908,-0.5617259339965155,-0.7782932635255163,0.5517003619657646,-0.12533009809240625,-0.10576855061332935,-0.8648997097923413,-0.3565777533097445,-0.17690957269816676,-0.9665825647327788,-0.3871774982055322,-0.6871426738116845,-1.0513742465423797,-0.48785251114623424,-1.8831100230955071,-1.4509489704076686,0.04795444814883043,-2.406192178702789,-2.740631004828978,-0.6593639978040515,-0.8077546856219137,-0.27505839913706903,-0.3384612323567201,-1.1638469977660644,-1.3556576475597404,-0.6319363886516881,-1.0061666167060577,-1.524244131647736,-0.6619559725370239,-0.42562658655649294,0.11270525757480243,-1.3877538953101538,-0.18521767482696305,-0.33318118680630465,-0.6458906630337192,-1.9142484156974744,-0.19414136487733624,-0.7616753285423429,-0.7541241897538253,-0.18246019937814306,-0.46622721506211234,-0.3963953399770494,0.3090547131252782,-1.5706101386968414,-1.0271327074664536,-0.20961556111337604,-0.6477391514842147,-0.7661507075821797,-0.9458668417956219,-0.5682049207695129,-1.2204879273166633,-1.5111046230670808,-0.11777623187274677,-1.1936764682837033,-1.3353278879539574,-0.6109819142605383,-1.1915991607113539,-1.695244274585074,-0.728931266625168,-0.5005654091300139,0.2870715195810326,-0.7387351729024608,-1.236887866726575,-0.6505891689386087,-1.3861174134767063,-0.7741283807072195,-0.10256164451992045,-0.22254332269669025,-1.3259492080511603,-0.6616948665075673,-1.087317374445795,0.5618063422166765,-2.0240287538705335,-1.0647591765605657,-0.5528252979100114,-0.8786473742803245,-0.31344584203216175,0.34626004646558817,1.0933771860279697,-0.36388123279645257,-1.4824585004396131,-1.50624199600361,-0.8872427125177238,-0.5479181411882378,-0.22043246343079453,-0.6552002806360878,-0.6364988294568976,-0.2592206909894751,-0.7178207542448942,-0.5185491413720005,0.20314370706289897,-0.5764074109617413,-0.9448831633642207,-0.6542342311927919,-0.8291217407589399,-0.5805994350213824,-0.23194111706666337,-0.07941882695297042,-0.1720539540216482,-2.052041335127617,-0.2198113701010599,-0.4889183257146345,0.054002728320900806,0.18555825246578284,-1.5788859338940409,0.2537341823722583,0.0695735173570795,0.10294586122814009,-0.49198074641689954,-0.10990786168720268,-0.7675741759253132,-0.40260713846521085,-0.467930016511398,-0.20219821961905216,0.3230148257778138,-0.5670376851247588,-1.379456034696116,0.030201271296323218,-0.8715726241865638 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="1aeb8c24-c9cc-4626-b280-c92d6d9a5170" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_1aeb8c24c9cc4626b280c92d6d9a5170 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.6950568827926984,-1.5495135250047412,-0.19902741579826388,-1.9906353896232334,0.47680580768530323,-0.6621580553754336,-0.3719515529639881,-1.1209996091719814,-0.6101207924751433,-0.5326754080792128,-1.8036656807688374,-0.7644959603156443,-1.4852703576921722,-0.5498461075661142,-0.013278024987963377,-1.8968375705458245,-0.9065751689588126,-1.2590438059020297,-1.471426775835742,-0.9342736637178735,-1.4387704424778494,-0.44553986055113026,-0.6611448450490962,-1.9313417895779719,0.20863075061567715,-1.0557865840462277,-1.0802047661838783,-1.2899841321627197,-0.2754509100560376,-0.547065140315689,-0.5238499652478994,-1.4055407085710634,0.48802584383470715,-0.8004553369495617,-1.6408904539360558,-0.43059138306768985,-0.7536178210150515,0.07615029251323213,-0.8294826153435076,-0.21291571165657974,-1.4245639856122627,-0.7765647071362203,0.12593781706738005,0.3215975512116549,-0.040465674594099776,-1.27265595625623,-0.5217426123766535,-1.5490446520360257,-0.867444883702168,0.21078683737664772,-1.573581396845754,-0.2887641468862011,-0.5356465545203979,-0.6970721549421751,-0.9244037059189305,-1.408056591459908,-0.5617259339965155,-0.7782932635255163,0.5517003619657646,-0.12533009809240625,-0.10576855061332935,-0.8648997097923413,-0.3565777533097445,-0.17690957269816676,-0.9665825647327788,-0.3871774982055322,-0.6871426738116845,-1.0513742465423797,-0.48785251114623424,-1.8831100230955071,-1.4509489704076686,0.04795444814883043,-2.406192178702789,-2.740631004828978,-0.6593639978040515,-0.8077546856219137,-0.27505839913706903,-0.3384612323567201,-1.1638469977660644,-1.3556576475597404,-0.6319363886516881,-1.0061666167060577,-1.524244131647736,-0.6619559725370239,-0.42562658655649294,0.11270525757480243,-1.3877538953101538,-0.18521767482696305,-0.33318118680630465,-0.6458906630337192,-1.9142484156974744,-0.19414136487733624,-0.7616753285423429,-0.7541241897538253,-0.18246019937814306,-0.46622721506211234,-0.3963953399770494,0.3090547131252782,-1.5706101386968414,-1.0271327074664536,-0.20961556111337604,-0.6477391514842147,-0.7661507075821797,-0.9458668417956219,-0.5682049207695129,-1.2204879273166633,-1.5111046230670808,-0.11777623187274677,-1.1936764682837033,-1.3353278879539574,-0.6109819142605383,-1.1915991607113539,-1.695244274585074,-0.728931266625168,-0.5005654091300139,0.2870715195810326,-0.7387351729024608,-1.236887866726575,-0.6505891689386087,-1.3861174134767063,-0.7741283807072195,-0.10256164451992045,-0.22254332269669025,-1.3259492080511603,-0.6616948665075673,-1.087317374445795,0.5618063422166765,-2.0240287538705335,-1.0647591765605657,-0.5528252979100114,-0.8786473742803245,-0.31344584203216175,0.34626004646558817,1.0933771860279697,-0.36388123279645257,-1.4824585004396131,-1.50624199600361,-0.8872427125177238,-0.5479181411882378,-0.22043246343079453,-0.6552002806360878,-0.6364988294568976,-0.2592206909894751,-0.7178207542448942,-0.5185491413720005,0.20314370706289897,-0.5764074109617413,-0.9448831633642207,-0.6542342311927919,-0.8291217407589399,-0.5805994350213824,-0.23194111706666337,-0.07941882695297042,-0.1720539540216482,-2.052041335127617,-0.2198113701010599,-0.4889183257146345,0.054002728320900806,0.18555825246578284,-1.5788859338940409,0.2537341823722583,0.0695735173570795,0.10294586122814009,-0.49198074641689954,-0.10990786168720268,-0.7675741759253132,-0.40260713846521085,-0.467930016511398,-0.20219821961905216,0.3230148257778138,-0.5670376851247588,-1.379456034696116,0.030201271296323218,-0.8715726241865638,-0.967 ...
