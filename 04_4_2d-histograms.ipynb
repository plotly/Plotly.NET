// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.8"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.8"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="ca729a9d-bd53-4a3f-aebe-309416b60cdc" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_ca729a9dbd534a3faebe309416b60cdc = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.19711168088241393,-0.9776422414714026,-0.1896898018575306,-1.2748713509219551,-0.8823568202443859,0.16806072114492676,-1.402119648777986,0.16745116392897152,0.020928081910335128,-0.4770801759463183,-0.2898164416955932,-1.4054446922496517,-1.2092183969781187,-1.3055892907519997,-0.9843331643317543,-0.2126544587380489,-0.2971629568076083,-1.195122938649809,-1.523584683374677,-2.633181308656383,-0.5635263421203007,-1.7348301891023845,-0.9436123508881615,-1.4301539540617898,0.02722497856142858,-1.0228566065009606,-1.0377688368399562,-0.823110380014805,-1.0433368897406399,-0.5128141334841325,1.0332091512426276,-1.4957403617920813,-1.1405439487576603,0.02428718050471379,-0.8116349076647873,0.020708683763629332,-0.20976941762563317,-0.6338082066803427,-1.0923438275660364,-0.06800333586737373,-0.721049424495533,-1.119534818481027,-1.372812855039857,0.47775362632422436,-1.3616411625098688,-0.6366663752256657,-0.7856501964080496,-0.5509801115599295,-0.9966082643063732,-0.7685770406901572,-0.4268491696185961,-0.6141859419706187,-1.923398606344581,-0.21399567452941082,-0.9160544974153815,-0.8266334564718024,-0.867479793698368,-1.2836879282480664,-0.906782840292704,-1.1376890205290704,-0.5752273925226721,-0.028002551864674374,-0.4552171149514879,-0.6584418356712508,0.14174547279521232,-1.271946186743675,-0.6180555630899048,-1.7325040325843224,-0.6565057050108374,-1.9619083589520345,-1.0170027010461422,-0.6787069700789149,-0.18371057332810803,0.5375397780063743,-0.7372498105218586,-0.7200065934566463,-0.6293521558291116,-0.6970769446067042,-0.2689067596088413,-0.5891505036475677,-0.0610781952971009,-0.3402585696963269,-1.7452799630397497,-0.9734258202498905,-0.8010802178491285,-0.47597968804051644,-1.2555800295269397,-0.2614769250560725,-1.0669954710533853,0.1411420897229766,-1.2461820305341174,-1.1800536759089648,-0.47817720721724055,-0.010600803779452828,-0.9414862324647778,0.05544280401113466,-1.078431496272157,-1.7413792303724343,0.0822174858837782,-1.1593603879596557,-0.8053906502082383,0.2152267376390271,-0.7582694535074475,0.05015933686136809,-0.6688720032205072,0.1512313796426531,-1.231357551718303,-1.571577580277894,-0.3197830119905861,-0.6448000396877396,-1.2750647210243125,0.3757015596785378,-1.1709227823944584,-0.37303810364245826,-0.1462988773985946,-0.6888017300582232,-0.10317607583788446,0.08005652151301657,-0.2615148338176312,-0.9763718855610382,-0.7142846293294767,-1.0317076288858131,-0.7766536820055843,0.43326893695389634,-0.9779989930701676,-1.0986070526511473,0.043427550721663266,-1.2121162642192882,-0.7312741075698933,-0.8395771217083142,-0.10840878588247094,-0.8193283844669992,-0.19485126894427657,-0.53944737284015,-1.0222380401549283,0.008759007062664526,-1.486318042078461,0.013412940131566575,0.4192800237713704,-0.7893439221959672,-1.8757162599863766,-1.831577019844124,-0.85221987848351,0.3913651893691211,-0.49837659437797616,-0.7001270689353123,-0.3266419066474426,-0.5764872993043616,-0.19700261141390318,-1.4040535123496953,-1.2712134981294967,-0.4762391541464357,-0.5204799290673349,0.21655619394216719,-0.5563987469191729,-0.15402127790411663,0.4227644807818246,-0.9442465799413824,-0.4689823272598942,-0.18242786259798383,-0.22518332243605738,-0.6400053295084367,-0.20737607494981047,-1.339108399383543,-0.6537279778681311,-0.2537082808684845,-1.9732615932814834,-0.3360667947451357,-0.7647719440614473,-1.115549747910734,0.12958311580901338,-0.7267621133515643,-1.1224477025473403,-1.2213209389633484,-0.29900491 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="2ce5145e-7b14-4b71-a817-c0c7c0106788" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_2ce5145e7b144b71a817c0c7c0106788 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.19711168088241393,-0.9776422414714026,-0.1896898018575306,-1.2748713509219551,-0.8823568202443859,0.16806072114492676,-1.402119648777986,0.16745116392897152,0.020928081910335128,-0.4770801759463183,-0.2898164416955932,-1.4054446922496517,-1.2092183969781187,-1.3055892907519997,-0.9843331643317543,-0.2126544587380489,-0.2971629568076083,-1.195122938649809,-1.523584683374677,-2.633181308656383,-0.5635263421203007,-1.7348301891023845,-0.9436123508881615,-1.4301539540617898,0.02722497856142858,-1.0228566065009606,-1.0377688368399562,-0.823110380014805,-1.0433368897406399,-0.5128141334841325,1.0332091512426276,-1.4957403617920813,-1.1405439487576603,0.02428718050471379,-0.8116349076647873,0.020708683763629332,-0.20976941762563317,-0.6338082066803427,-1.0923438275660364,-0.06800333586737373,-0.721049424495533,-1.119534818481027,-1.372812855039857,0.47775362632422436,-1.3616411625098688,-0.6366663752256657,-0.7856501964080496,-0.5509801115599295,-0.9966082643063732,-0.7685770406901572,-0.4268491696185961,-0.6141859419706187,-1.923398606344581,-0.21399567452941082,-0.9160544974153815,-0.8266334564718024,-0.867479793698368,-1.2836879282480664,-0.906782840292704,-1.1376890205290704,-0.5752273925226721,-0.028002551864674374,-0.4552171149514879,-0.6584418356712508,0.14174547279521232,-1.271946186743675,-0.6180555630899048,-1.7325040325843224,-0.6565057050108374,-1.9619083589520345,-1.0170027010461422,-0.6787069700789149,-0.18371057332810803,0.5375397780063743,-0.7372498105218586,-0.7200065934566463,-0.6293521558291116,-0.6970769446067042,-0.2689067596088413,-0.5891505036475677,-0.0610781952971009,-0.3402585696963269,-1.7452799630397497,-0.9734258202498905,-0.8010802178491285,-0.47597968804051644,-1.2555800295269397,-0.2614769250560725,-1.0669954710533853,0.1411420897229766,-1.2461820305341174,-1.1800536759089648,-0.47817720721724055,-0.010600803779452828,-0.9414862324647778,0.05544280401113466,-1.078431496272157,-1.7413792303724343,0.0822174858837782,-1.1593603879596557,-0.8053906502082383,0.2152267376390271,-0.7582694535074475,0.05015933686136809,-0.6688720032205072,0.1512313796426531,-1.231357551718303,-1.571577580277894,-0.3197830119905861,-0.6448000396877396,-1.2750647210243125,0.3757015596785378,-1.1709227823944584,-0.37303810364245826,-0.1462988773985946,-0.6888017300582232,-0.10317607583788446,0.08005652151301657,-0.2615148338176312,-0.9763718855610382,-0.7142846293294767,-1.0317076288858131,-0.7766536820055843,0.43326893695389634,-0.9779989930701676,-1.0986070526511473,0.043427550721663266,-1.2121162642192882,-0.7312741075698933,-0.8395771217083142,-0.10840878588247094,-0.8193283844669992,-0.19485126894427657,-0.53944737284015,-1.0222380401549283,0.008759007062664526,-1.486318042078461,0.013412940131566575,0.4192800237713704,-0.7893439221959672,-1.8757162599863766,-1.831577019844124,-0.85221987848351,0.3913651893691211,-0.49837659437797616,-0.7001270689353123,-0.3266419066474426,-0.5764872993043616,-0.19700261141390318,-1.4040535123496953,-1.2712134981294967,-0.4762391541464357,-0.5204799290673349,0.21655619394216719,-0.5563987469191729,-0.15402127790411663,0.4227644807818246,-0.9442465799413824,-0.4689823272598942,-0.18242786259798383,-0.22518332243605738,-0.6400053295084367,-0.20737607494981047,-1.339108399383543,-0.6537279778681311,-0.2537082808684845,-1.9732615932814834,-0.3360667947451357,-0.7647719440614473,-1.115549747910734,0.12958311580901338,-0.7267621133515643,-1.1224477025473403,-1.2213209389633484,-0.299004916914931 ...
