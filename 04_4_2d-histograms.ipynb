// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.11"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.11"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2D chart can be created using the `Chart.Histogram2D` or `Chart.Histogram2DContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2DContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="68cd4a3f-3aba-4664-9e95-c0338c2eeb4b" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_68cd4a3f3aba46649e95c0338c2eeb4b = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2Dcontour","x":[-1.3201360076094173,0.21396455872253284,0.12924391017800707,-2.0598766700641633,0.00290711009984701,-0.9132059961165311,-1.4838682389788085,-0.3962253145808281,-1.694568409049952,-0.8509894693048022,-1.6191331828314701,-0.5838603177342441,-1.2002421792764248,-0.7102182006300566,-0.5999452563516168,-1.003669367168649,-1.1179128298133914,-1.5989909324070006,-0.6363167934797223,-0.4063196032756913,-1.1804151475515274,-0.5061393451070908,-0.7868299416690789,-1.2626466414833264,-0.9572741183661662,-0.9188702999877809,-2.0265365897349157,-0.9280907852720177,-0.9785707730464529,-0.9246528349891248,-1.0535892129079298,-1.6183683108138003,-1.2181858860974442,-1.2940535448634911,-0.2726513505675323,-1.119678385533666,-0.9156301570646025,-0.0901955426854214,-0.9889128775233321,-0.26640042731671054,-0.7277636626870605,-0.3963690263115289,-1.2032156353996668,-1.8091560757028846,-1.3103582748834088,-0.019525055012702852,-1.1445872668480468,-1.1281490194401207,-0.5901295749032442,-0.9353554334498123,-0.5610679471747005,-0.3435201801471819,-1.1973391169318648,-0.6447377102285777,-0.029056393101241307,-0.9472704115212545,-0.17671822495418454,-1.153328016478656,-1.1539463692570635,-1.5009779176495293,-1.1702452227895455,-0.8287204866907749,-0.9574361596692056,-0.7930115489092597,-0.14932798391113822,-0.7553315347920592,0.03783784165474002,-0.7938639297946396,-1.2200916843417005,-0.10969621083710401,-1.4434781422484195,-0.638096824965947,0.05905892535952273,-0.7405774795641403,0.10971775573655929,-1.5506219872266012,-0.8076022565265909,-1.0720063918097102,-0.05885551331188599,-2.074028499210999,-0.8839452918665794,0.6045533428949659,-0.3975489729705028,0.05190221439136922,-0.22185962425989936,-0.6156845219513096,-0.1499121514215127,-1.646811916364887,-1.067605231842272,-0.07369191927513052,-1.4352534586396668,-1.8633649476937384,-0.8608303230433715,-0.5242978565088816,-1.0159237732528972,-0.9534129548988122,-0.9862977795422786,-0.9418441247477015,-0.5944162270078815,-1.3780907708044277,-0.30438684412211775,0.3634123376126601,-1.0378929049622916,-0.008955600728365543,-0.8035304242299846,-0.1851845527135333,-0.9338398617859374,-0.10610440859832082,-0.5938424712581217,-0.9306210531140331,-0.012726598114333854,-0.6582787905019553,-0.44159199168181956,-0.5813094940599123,-0.5501710938269485,-0.5826442939831197,-0.6898352058719985,-0.6868592236272852,-0.5973896557911393,-0.1870115952282404,-1.2388737921195299,-1.576547934500661,-1.191834749073235,-0.07923649029598623,-1.6721788967173845,-0.5514556096288978,-0.20696875843146734,-0.49139423093951423,-0.6322787742983017,-0.5239606398250646,-1.3557066735629237,-1.1908101172077958,-1.1855877306679337,0.22590380132717813,0.029700304057095783,-0.6414544395493583,0.2551543262367695,-0.9400094085092401,-0.42671143500363307,-0.7190244157550953,0.1460813270561535,-1.4897199108226162,-1.7089216865866275,-0.6180063908865424,-1.2557330092212724,0.2928559161244083,-1.5306226750850431,-0.289858642246342,-0.028955948829089695,-0.23111709039360662,-0.5827315776981021,-0.2857893156211023,-1.227729835899061,-0.9759864515388941,-0.8605174806624534,-1.0510765169338128,-0.24952613620811298,0.33504446741201777,-0.0003689019509223179,-0.46086195046973677,-0.04478947622838336,-0.7042082526768187,0.8550109513630284,-1.254613476595766,0.4347252706796396,-0.31421660689323627,0.29557709439069957,-0.072952427060687,-0.23432157621811328,-1.644506900080045,-1.27233023009897,-0.8561379339430907,-1.1213219862269201,-1.730096802330 ...

// %%
let histogram2D = 
    Chart.Histogram2D (x,y)

// %%
histogram2D
// Out:
// <div id="7c051a81-e27e-465a-a707-0a1f71d143b0" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_7c051a81e27e465aa7070a1f71d143b0 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2D","x":[-1.3201360076094173,0.21396455872253284,0.12924391017800707,-2.0598766700641633,0.00290711009984701,-0.9132059961165311,-1.4838682389788085,-0.3962253145808281,-1.694568409049952,-0.8509894693048022,-1.6191331828314701,-0.5838603177342441,-1.2002421792764248,-0.7102182006300566,-0.5999452563516168,-1.003669367168649,-1.1179128298133914,-1.5989909324070006,-0.6363167934797223,-0.4063196032756913,-1.1804151475515274,-0.5061393451070908,-0.7868299416690789,-1.2626466414833264,-0.9572741183661662,-0.9188702999877809,-2.0265365897349157,-0.9280907852720177,-0.9785707730464529,-0.9246528349891248,-1.0535892129079298,-1.6183683108138003,-1.2181858860974442,-1.2940535448634911,-0.2726513505675323,-1.119678385533666,-0.9156301570646025,-0.0901955426854214,-0.9889128775233321,-0.26640042731671054,-0.7277636626870605,-0.3963690263115289,-1.2032156353996668,-1.8091560757028846,-1.3103582748834088,-0.019525055012702852,-1.1445872668480468,-1.1281490194401207,-0.5901295749032442,-0.9353554334498123,-0.5610679471747005,-0.3435201801471819,-1.1973391169318648,-0.6447377102285777,-0.029056393101241307,-0.9472704115212545,-0.17671822495418454,-1.153328016478656,-1.1539463692570635,-1.5009779176495293,-1.1702452227895455,-0.8287204866907749,-0.9574361596692056,-0.7930115489092597,-0.14932798391113822,-0.7553315347920592,0.03783784165474002,-0.7938639297946396,-1.2200916843417005,-0.10969621083710401,-1.4434781422484195,-0.638096824965947,0.05905892535952273,-0.7405774795641403,0.10971775573655929,-1.5506219872266012,-0.8076022565265909,-1.0720063918097102,-0.05885551331188599,-2.074028499210999,-0.8839452918665794,0.6045533428949659,-0.3975489729705028,0.05190221439136922,-0.22185962425989936,-0.6156845219513096,-0.1499121514215127,-1.646811916364887,-1.067605231842272,-0.07369191927513052,-1.4352534586396668,-1.8633649476937384,-0.8608303230433715,-0.5242978565088816,-1.0159237732528972,-0.9534129548988122,-0.9862977795422786,-0.9418441247477015,-0.5944162270078815,-1.3780907708044277,-0.30438684412211775,0.3634123376126601,-1.0378929049622916,-0.008955600728365543,-0.8035304242299846,-0.1851845527135333,-0.9338398617859374,-0.10610440859832082,-0.5938424712581217,-0.9306210531140331,-0.012726598114333854,-0.6582787905019553,-0.44159199168181956,-0.5813094940599123,-0.5501710938269485,-0.5826442939831197,-0.6898352058719985,-0.6868592236272852,-0.5973896557911393,-0.1870115952282404,-1.2388737921195299,-1.576547934500661,-1.191834749073235,-0.07923649029598623,-1.6721788967173845,-0.5514556096288978,-0.20696875843146734,-0.49139423093951423,-0.6322787742983017,-0.5239606398250646,-1.3557066735629237,-1.1908101172077958,-1.1855877306679337,0.22590380132717813,0.029700304057095783,-0.6414544395493583,0.2551543262367695,-0.9400094085092401,-0.42671143500363307,-0.7190244157550953,0.1460813270561535,-1.4897199108226162,-1.7089216865866275,-0.6180063908865424,-1.2557330092212724,0.2928559161244083,-1.5306226750850431,-0.289858642246342,-0.028955948829089695,-0.23111709039360662,-0.5827315776981021,-0.2857893156211023,-1.227729835899061,-0.9759864515388941,-0.8605174806624534,-1.0510765169338128,-0.24952613620811298,0.33504446741201777,-0.0003689019509223179,-0.46086195046973677,-0.04478947622838336,-0.7042082526768187,0.8550109513630284,-1.254613476595766,0.4347252706796396,-0.31421660689323627,0.29557709439069957,-0.072952427060687,-0.23432157621811328,-1.644506900080045,-1.27233023009897,-0.8561379339430907,-1.1213219862269201,-1.7300968023307997,-1 ...
