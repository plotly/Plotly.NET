// %%
#r "nuget: Plotly.NET, 3.0.0"
#r "nuget: Plotly.NET.Interactive, 3.0.0"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// **Summary:** This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2D chart can be created using the `Chart.Histogram2D` or `Chart.Histogram2DContour` functions.

// %%
let histogramContour = Chart.Histogram2DContour (x,y,ContourLine=Line.init(Width=0.))

// %%
histogramContour
// Out:
// <div id="e07e77d8-dc90-4187-80d9-e051273fd988"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_e07e77d8dc90418780d9e051273fd988 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.6.3.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.8741623680041798,-1.6204432711175492,0.4468310416556983,-1.9249152933824765,-0.877938208139668,-0.5521331100816569,0.27617038271725003,-1.767425685775999,-1.4815960874859768,-0.8682725824844109,-0.6680530154966877,-0.362894256854441,-0.22791849819392973,-1.8401207314684132,-1.0894688861837651,-1.4717312511855423,-0.5279602696418493,-0.9276745698834433,-2.6793717169874975,-0.07279788752556371,-0.5021774309062679,-1.1027357283913146,-0.1082660916070115,-0.8578319399906611,-0.7537692723994072,-0.4819813261147066,-0.5954125295989214,-1.2717053116293284,-0.017163160386273746,-0.7009272911099009,-1.9570989350694428,-0.9614348854060188,-0.5729252742284627,0.7327401012042454,-0.9002951359947653,-1.312631623240506,-0.4127142389278762,-0.36179531447233915,-1.5635499985101018,-0.4284592309246835,-1.1124462109579,-0.9640523685418388,-2.44753017688857,-1.899736249731262,-1.3134527073443703,-1.461316335082022,-0.6468119897481295,-0.5347881238419372,-0.928648904452785,-2.0846226845229965,-0.6495710884217567,-1.1339458754760792,-1.8527307137000333,-1.1574697313929767,-0.7148068104921343,-0.6937157210913398,-1.30921792699229,-0.15316038333919868,-1.1756317034935726,-1.533004891742168,0.2237454934692874,-1.200601652