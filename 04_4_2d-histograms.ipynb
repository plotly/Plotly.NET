// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.15"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.15"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=04_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/04_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/04_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2D chart can be created using the `Chart.Histogram2D` or `Chart.Histogram2DContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2DContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="8e08d8c0-a65a-4de8-ba3a-8f77731ea35a"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_8e08d8c0a65a4de8ba3a8f77731ea35a = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.6584759494654768,-1.3187519380851938,-0.7248611246838311,-1.6991883882076677,-0.8892463130177395,-1.2534997183942345,-1.1574428260729364,-0.978653618618615,-1.4725205875523644,-1.6631250426016329,-0.48938206772936615,-1.0229372507191328,-0.9193703643567785,-0.6666881578801618,-1.2543596989919275,-0.679467765080928,-0.6213553550873476,0.6524851994231541,-0.9401981851547028,-0.9948970136427167,-0.6806000145956259,-1.1290894433907148,0.22563444612699812,-0.48749105845026347,-0.2591473397320597,-0.6184819368523455,-1.2337223850558299,-0.5863429317890494,-0.6439290663748439,0.22954671392358594,-1.147742562327286,-0.6183121412768987,-0.25231168049267116,-1.3889556912728631,-0.9205963820417236,-0.16995299615934634,-1.1596129056238509,-0.8432324001585584,-0.7911410330844886,-1.2846546467401747,-0.5226469682120322,-0.7871790519784904,-0.9185551269714688,-1.5527642085371336,1.1826737180865834,-1.3829012267274121,-1.9663978723118385,-0.10893628606792649,-0.13420643925433395,-1.5430605147718635,-1.1785496196370913,-0.8271065025735279,-0.28159147519041083,-0.8078130293794314,-0.5399449227958033,-0.1749617380314481,-0.6421051801501059,-0.9068680729875733,-0.5397287542798799,-0.6113065595609148,-0.3371994494451731,-0.9964205480623074,-0.5647144208532937,-0.44438562969490697,-0.04496300734672931,-1.6633269655968557,-2.141713021688431,-1.4855625547558082,-0.4418870525457279,-2.4197736097229687,-0.9372796548398009,-1.7175142573937028,-1.0454890782874136,-0.04391075902658548,-0.25063148463677387,-0.8749596059659575,-1.6119698418354715,-2.0994282443847005,-1.3712824337775915,-0.34187073969214327,-0.4769224243797524,0.14885825309768896,-1.2206322448938862,-1.0400599243451651,-0.10898996543841055,-1.029587221126009,-0.21767387643288183,0.540515178689723,-0.3490396131147288,-1.1095830742825674,-0.505467425546173,-0.7228630761796943,-1.031293496933576,-0.1350014226402323,-0.08723191074817194,-0.3792787557013875,-0.7948656800387254,-0.0053235757876370915,-0.37000776209305,-1.231122135925176,-0.7190387831671715,0.2770017259456308,-0.993821266819432,-1.4381826226255154,0.4303451942774056,-0.19748859007894032,0.08064155704306164,-0.07875953119560286,-0.4810010792159718,-0.5396765007485131,-0.8088866865237156,-0.8434529317926374,-0.08325126367128166,0.3949027594906366,-0.845965980565901,-0.885168689445949,-1.4166440647282053,-1.2684150497319482,-0.5527319703689889,-0.480588896581984,-0.8223981662819446,-0.4405022905418684,-0.8448081790020061,-1.666812240511156,-0.6129314037674466,-0.3331807961893321,-1.50890006217691,-0.18159199091529932,-0.2331056295091683,-0.40664811443958143,-0.2739849171708091,-1.8418353149167914,-0.9218273665337491,-0.707730111437588,-1.2961441459441168,0.10150355547529488,-0.8292887700818489,-0.19049911407287873,-0.6538212747880261,-1.047991382115919,-0.3294866025924472,-0.4684637334306308,-0.7126699312388368,-1.0252221172632168,-0.08196292902702484,-1.254107230819308,-0.5364294859942206,-1.618962666887383,-0.550886108168305,-1.2711424029571257,-0.0019831421707108277,-0.6527937637945163,-0.17982916911043678,-0.7822149756104992,-0.6717994634058666,-0.08440762955733133,-0.03685048142759184,-0.3830663903734366,-1.0933365003732098,0.13687537892974067,-0.62352277692387,-0.6501569223400321,-0.35028789078038325,-0.7008211573043928,0.42868961021149954,-0.4591858749529647,-0.798050053714636,-0.35043673979049983,-0.5238359514522347,-0.4773508695659788,-0.036789964652455875,-0.7680665809636509,-1.151299951516725,-0.7592441053218605,-1.3158084573796218,-1.0016445190932604, ...

// %%
let histogram2D = 
    Chart.Histogram2D (x,y)

// %%
histogram2D
// Out:
// <div id="fc402a81-c150-4163-b73f-b43a0338352a"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_fc402a81c1504163b73fb43a0338352a = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.4.2.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.6584759494654768,-1.3187519380851938,-0.7248611246838311,-1.6991883882076677,-0.8892463130177395,-1.2534997183942345,-1.1574428260729364,-0.978653618618615,-1.4725205875523644,-1.6631250426016329,-0.48938206772936615,-1.0229372507191328,-0.9193703643567785,-0.6666881578801618,-1.2543596989919275,-0.679467765080928,-0.6213553550873476,0.6524851994231541,-0.9401981851547028,-0.9948970136427167,-0.6806000145956259,-1.1290894433907148,0.22563444612699812,-0.48749105845026347,-0.2591473397320597,-0.6184819368523455,-1.2337223850558299,-0.5863429317890494,-0.6439290663748439,0.22954671392358594,-1.147742562327286,-0.6183121412768987,-0.25231168049267116,-1.3889556912728631,-0.9205963820417236,-0.16995299615934634,-1.1596129056238509,-0.8432324001585584,-0.7911410330844886,-1.2846546467401747,-0.5226469682120322,-0.7871790519784904,-0.9185551269714688,-1.5527642085371336,1.1826737180865834,-1.3829012267274121,-1.9663978723118385,-0.10893628606792649,-0.13420643925433395,-1.5430605147718635,-1.1785496196370913,-0.8271065025735279,-0.28159147519041083,-0.8078130293794314,-0.5399449227958033,-0.1749617380314481,-0.6421051801501059,-0.9068680729875733,-0.5397287542798799,-0.6113065595609148,-0.3371994494451731,-0.9964205480623074,-0.5647144208532937,-0.44438562969490697,-0.04496300734672931,-1.6633269655968557,-2.141713021688431,-1.4855625547558082,-0.4418870525457279,-2.4197736097229687,-0.9372796548398009,-1.7175142573937028,-1.0454890782874136,-0.04391075902658548,-0.25063148463677387,-0.8749596059659575,-1.6119698418354715,-2.0994282443847005,-1.3712824337775915,-0.34187073969214327,-0.4769224243797524,0.14885825309768896,-1.2206322448938862,-1.0400599243451651,-0.10898996543841055,-1.029587221126009,-0.21767387643288183,0.540515178689723,-0.3490396131147288,-1.1095830742825674,-0.505467425546173,-0.7228630761796943,-1.031293496933576,-0.1350014226402323,-0.08723191074817194,-0.3792787557013875,-0.7948656800387254,-0.0053235757876370915,-0.37000776209305,-1.231122135925176,-0.7190387831671715,0.2770017259456308,-0.993821266819432,-1.4381826226255154,0.4303451942774056,-0.19748859007894032,0.08064155704306164,-0.07875953119560286,-0.4810010792159718,-0.5396765007485131,-0.8088866865237156,-0.8434529317926374,-0.08325126367128166,0.3949027594906366,-0.845965980565901,-0.885168689445949,-1.4166440647282053,-1.2684150497319482,-0.5527319703689889,-0.480588896581984,-0.8223981662819446,-0.4405022905418684,-0.8448081790020061,-1.666812240511156,-0.6129314037674466,-0.3331807961893321,-1.50890006217691,-0.18159199091529932,-0.2331056295091683,-0.40664811443958143,-0.2739849171708091,-1.8418353149167914,-0.9218273665337491,-0.707730111437588,-1.2961441459441168,0.10150355547529488,-0.8292887700818489,-0.19049911407287873,-0.6538212747880261,-1.047991382115919,-0.3294866025924472,-0.4684637334306308,-0.7126699312388368,-1.0252221172632168,-0.08196292902702484,-1.254107230819308,-0.5364294859942206,-1.618962666887383,-0.550886108168305,-1.2711424029571257,-0.0019831421707108277,-0.6527937637945163,-0.17982916911043678,-0.7822149756104992,-0.6717994634058666,-0.08440762955733133,-0.03685048142759184,-0.3830663903734366,-1.0933365003732098,0.13687537892974067,-0.62352277692387,-0.6501569223400321,-0.35028789078038325,-0.7008211573043928,0.42868961021149954,-0.4591858749529647,-0.798050053714636,-0.35043673979049983,-0.5238359514522347,-0.4773508695659788,-0.036789964652455875,-0.7680665809636509,-1.151299951516725,-0.7592441053218605,-1.3158084573796218,-1.0016445190932604,-1.1863 ...
