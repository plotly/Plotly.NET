// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta10"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta10"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="5c466e93-ef0e-428f-86da-6bf67ce44086" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_5c466e93ef0e428f86da6bf67ce44086 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.3322728501952692,0.3901431538176391,-1.4049134209725218,-1.4249171811989445,-1.541569038882861,-0.8094427535958844,-1.7398706961631245,-0.18594611260252314,-1.3593724878112714,-0.3589184030839818,-0.7890390339665931,-0.8320536532425767,-0.9009404739305111,-0.8074174229098648,-1.3143424639428467,-0.9610708828019525,-0.7647652464635463,-0.2442579459320693,-0.6703048935786836,-1.587845274361517,-1.2110787677780004,-0.9500851149653234,-1.961363968207838,-1.4588849945706843,-0.887191739609518,-0.7453937529090258,-0.20660677731848942,-2.0914110291730155,0.19993070829737292,-0.2859111719806592,-0.16864102013570603,-0.6732834428571925,-0.5167942864451227,-0.5242124189837214,-0.4898661310831324,-1.2925514154298539,0.3079591287951523,-1.6898632192660523,-1.6187902633779025,-0.31539049815609443,-2.0994049107974093,-0.35050254860995267,-0.7639636945166025,-0.26173146414744,-1.1361622785547592,-2.3228578062471987,-1.320227710636439,-0.6322723642652518,-0.8283388235722646,-1.6320465265033826,-0.9243533705114628,-0.9596152626617959,-0.8316542557928059,-0.4131211054420763,-1.5178472620828152,-1.1959463221954636,-0.3692030969239326,-1.7700752283929106,-0.7131560730731319,-1.556531927803244,-1.948685436798756,-0.796142898719536,0.25366084854495996,-1.6338970296299404,-1.5424653665855625,-0.9624327341262352,0.1644767794493044,-0.7774062620373098,-1.3381269613088005,-0.602934385796838,-0.6724220126721936,-0.4519445586426,-1.0657107144631222,0.25048564273261953,-1.2164947991617174,-0.4120733056509347,-0.32084890531553417,0.07799119902659557,-0.025484060510843176,-0.6257641199235788,-1.356217475696438,-1.4587142420574892,-0.9783585942658322,-1.8761729197330947,-0.6841891023617175,-0.9602778677099116,-0.9716665673998292,-0.7005336618421062,-0.07589247395984,-0.4124950085400991,0.006347502744428191,-0.657217092144889,-0.9150519106131957,-1.3083200861937057,-0.6608969020971484,-1.1404777721065398,0.29691588589552564,-0.9533817496190081,-0.31936806557017267,-0.8244683367058475,-0.3702121348250178,-0.6964822523812995,-1.2890347401561961,-0.3531852362699872,-0.6789580905329528,-1.6438938172923816,0.028314337981892757,-0.3298434058883682,-1.3329530738478372,-1.5056610974767253,-1.4624129450889591,-0.8630130083398642,-0.9338749981158607,-0.5615109611723712,-0.4356848499016902,-0.5689725586713859,-0.14881467589642794,-0.4624670024440807,-0.7595732832577285,-1.4465672300648804,-1.0801846992461506,-0.33411405022743823,-0.30974887890999386,-0.5395334195968351,-0.6810201822856422,-0.47752759859371596,-1.3573096924278987,-0.5825405176656178,-0.9829807318298788,-1.3696719543775655,-0.4815518421309574,-0.8248404275904803,-1.0415559044579488,-0.9892894678351632,-0.471505232456268,-1.0511191381421072,-1.4113585012046215,-1.4541608531078907,-1.3374597267005712,-1.21457914021715,-1.4259578705488103,-0.7037667602094239,-0.29005145099754254,1.1078227281983226,0.38452780311349544,0.009862267106480749,-1.4922695158359078,0.10017843090947465,-0.013685882290053963,0.043635430741616466,-0.07715297662929954,-0.805684531727062,-0.3237986273294111,0.01688488917177844,-0.5967316843766723,-0.27014432414742645,-1.3503522825291454,-0.5185444974101115,-0.3872514512271996,0.022943809522515846,-1.710568108083177,0.025307864833706728,0.2050083425152064,-0.03421717275435954,0.38478248862426145,-1.4282821245033896,-1.105849230770962,-1.4611347239359622,-1.5159036128746037,-0.276216379149607,-0.640612635412602,-1.064966764232159,-0.9576031772022896,-1.4722594741047588,-0.17930475 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="c97f1c73-e4c7-4ab4-8903-ab66c51d323e" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_c97f1c73e4c74ab48903ab66c51d323e = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.3322728501952692,0.3901431538176391,-1.4049134209725218,-1.4249171811989445,-1.541569038882861,-0.8094427535958844,-1.7398706961631245,-0.18594611260252314,-1.3593724878112714,-0.3589184030839818,-0.7890390339665931,-0.8320536532425767,-0.9009404739305111,-0.8074174229098648,-1.3143424639428467,-0.9610708828019525,-0.7647652464635463,-0.2442579459320693,-0.6703048935786836,-1.587845274361517,-1.2110787677780004,-0.9500851149653234,-1.961363968207838,-1.4588849945706843,-0.887191739609518,-0.7453937529090258,-0.20660677731848942,-2.0914110291730155,0.19993070829737292,-0.2859111719806592,-0.16864102013570603,-0.6732834428571925,-0.5167942864451227,-0.5242124189837214,-0.4898661310831324,-1.2925514154298539,0.3079591287951523,-1.6898632192660523,-1.6187902633779025,-0.31539049815609443,-2.0994049107974093,-0.35050254860995267,-0.7639636945166025,-0.26173146414744,-1.1361622785547592,-2.3228578062471987,-1.320227710636439,-0.6322723642652518,-0.8283388235722646,-1.6320465265033826,-0.9243533705114628,-0.9596152626617959,-0.8316542557928059,-0.4131211054420763,-1.5178472620828152,-1.1959463221954636,-0.3692030969239326,-1.7700752283929106,-0.7131560730731319,-1.556531927803244,-1.948685436798756,-0.796142898719536,0.25366084854495996,-1.6338970296299404,-1.5424653665855625,-0.9624327341262352,0.1644767794493044,-0.7774062620373098,-1.3381269613088005,-0.602934385796838,-0.6724220126721936,-0.4519445586426,-1.0657107144631222,0.25048564273261953,-1.2164947991617174,-0.4120733056509347,-0.32084890531553417,0.07799119902659557,-0.025484060510843176,-0.6257641199235788,-1.356217475696438,-1.4587142420574892,-0.9783585942658322,-1.8761729197330947,-0.6841891023617175,-0.9602778677099116,-0.9716665673998292,-0.7005336618421062,-0.07589247395984,-0.4124950085400991,0.006347502744428191,-0.657217092144889,-0.9150519106131957,-1.3083200861937057,-0.6608969020971484,-1.1404777721065398,0.29691588589552564,-0.9533817496190081,-0.31936806557017267,-0.8244683367058475,-0.3702121348250178,-0.6964822523812995,-1.2890347401561961,-0.3531852362699872,-0.6789580905329528,-1.6438938172923816,0.028314337981892757,-0.3298434058883682,-1.3329530738478372,-1.5056610974767253,-1.4624129450889591,-0.8630130083398642,-0.9338749981158607,-0.5615109611723712,-0.4356848499016902,-0.5689725586713859,-0.14881467589642794,-0.4624670024440807,-0.7595732832577285,-1.4465672300648804,-1.0801846992461506,-0.33411405022743823,-0.30974887890999386,-0.5395334195968351,-0.6810201822856422,-0.47752759859371596,-1.3573096924278987,-0.5825405176656178,-0.9829807318298788,-1.3696719543775655,-0.4815518421309574,-0.8248404275904803,-1.0415559044579488,-0.9892894678351632,-0.471505232456268,-1.0511191381421072,-1.4113585012046215,-1.4541608531078907,-1.3374597267005712,-1.21457914021715,-1.4259578705488103,-0.7037667602094239,-0.29005145099754254,1.1078227281983226,0.38452780311349544,0.009862267106480749,-1.4922695158359078,0.10017843090947465,-0.013685882290053963,0.043635430741616466,-0.07715297662929954,-0.805684531727062,-0.3237986273294111,0.01688488917177844,-0.5967316843766723,-0.27014432414742645,-1.3503522825291454,-0.5185444974101115,-0.3872514512271996,0.022943809522515846,-1.710568108083177,0.025307864833706728,0.2050083425152064,-0.03421717275435954,0.38478248862426145,-1.4282821245033896,-1.105849230770962,-1.4611347239359622,-1.5159036128746037,-0.276216379149607,-0.640612635412602,-1.064966764232159,-0.9576031772022896,-1.4722594741047588,-0.179304751866646 ...
