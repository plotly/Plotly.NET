// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta9"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta9"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.github.io/Plotly.NET/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.github.io/Plotly.NET/img/badge-script.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.github.io/Plotly.NET/img/badge-notebook.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="ce692fef-94dd-4eb1-ad19-bb1b39d69c71" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_ce692fef94dd4eb1ad19bb1b39d69c71 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.358613583642072,-0.36447458715761305,-0.5914031860101463,-0.7074284127121988,-0.9487466693390088,-1.4145099883459213,-1.226933996069238,-0.6190803442224954,-1.2763523158850925,-1.7022907630722037,-0.5808734644913993,0.10840912078696074,-1.4890297420601235,-0.9217878686054021,-0.841949405307442,-1.1790109210055038,-0.44815182728073877,-0.9037748924881824,-1.3072159248804145,-1.5881225072494798,-0.7629585739051552,-0.02927462569318917,-1.4464445975667846,-2.0679563755580483,-1.2652785324174338,-0.5497799294149268,-1.3001960770819048,-0.45924779578267,-0.5200422954588098,-2.384060824840116,-1.0082322854639967,-1.9518819404837369,-1.1976253375072978,0.1268430127796063,-1.8541327762313187,-1.487220567758474,-1.5932860001523828,-1.5550874344912902,-0.35499337333458714,-0.8752225312579465,-0.997084510695305,-0.48789993766784495,0.5135018751938177,-0.5773517383510043,0.23417799305857978,-0.4324032183989852,-1.455361307670379,-0.21155128813444946,-1.809602177981087,-0.32426607935717455,-1.2311006705183425,-0.6963139570375018,-0.45814325093337643,-0.6211628839163915,-0.8260777350094801,-0.08429890097250503,-1.2778043123943164,-1.723855037985254,-1.064080489918187,-1.45682260427024,-0.20227289769965728,-1.833094650202496,-1.0752808424056202,-0.331217264229552,-1.1430240090849078,-0.8007752814289547,-1.5924938090762901,-1.8917075147921651,-0.45241667506020977,-0.5996131982862651,-1.1207380368680422,-1.3599620192481976,-0.12687063713848634,-0.09069334963470588,-0.606382421834576,-1.274784273909077,-1.922171481693777,-0.5323501175695255,-0.7527657400524046,-1.2273464271791095,-1.221541804032468,-1.2654546074796342,-1.4202904872756803,-0.9910239583786321,-0.31610852266507394,-0.4645883385722762,-0.4507393165447694,-0.8812136205637948,-1.0708082622984973,-0.14386947646037684,-0.6055852731331017,-0.9678509094733606,-0.5877865667342037,-1.0642398317791568,-0.9666382566451738,-0.9320302146740319,-0.5359441832867944,-1.1035446527105834,-0.9237491350289262,-0.05001933526857982,-0.3984083840110025,-1.1759614699866652,-1.942836848176253,-0.8441904422278833,0.2331215457982151,-0.9592762081660619,-0.961367144666087,-1.3390213313143038,-0.3760062418463476,0.14215018250562417,-1.1751181897980745,-0.6969489643272052,-0.24844481509431066,-0.3626889146157966,-0.30787390827290306,-0.7566002147602289,-0.07258647820476372,-1.5581709882774488,0.386173063258063,-0.07183816232061746,-0.6289646979207015,-0.6335285203038962,-1.0324598001875525,-0.7441621541822308,0.10122836246329137,-1.5375098733718056,-1.5582240751011305,0.0978217124087356,-1.2739882479109685,-1.2289305111560185,-0.5707508274926087,-1.5684052389962826,-1.0843400774263794,-0.2518235965871985,-0.2254071625678577,-0.6989180453978728,-1.999386172063549,-1.226003764142183,-0.657617561721026,0.2899654751281444,-0.8469031706615184,-1.137908509238187,-1.4697877747405212,-0.4283560847182343,-2.1160371165121594,0.11893520809655489,-1.5255471820776474,-0.23430981722678246,-0.4218110502894875,-1.4102918213768172,-0.9577591344490812,0.4416848805765651,-0.40317114562891454,-0.7201127445710416,-1.154901920329747,-0.4030992838459526,-0.8987034851614919,-1.1283163853611369,-1.246795895195798,0.00402644200430613,-0.1693683966952036,-0.7263608031866726,-0.8241727667784494,0.09703130645342517,0.010599139685680381,-0.10633996253250921,-0.7814645230184973,-1.2153521259677484,0.9916459738130269,-0.09734015429800036,-0.7626373205543453,-0.30158051427345456,-1.1461313122155352,-0.04968022108049397,-0.45123407733 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="692f8de5-0e1b-4b34-aa13-458c66eb0fbe" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_692f8de50e1b4b34aa13458c66eb0fbe = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.358613583642072,-0.36447458715761305,-0.5914031860101463,-0.7074284127121988,-0.9487466693390088,-1.4145099883459213,-1.226933996069238,-0.6190803442224954,-1.2763523158850925,-1.7022907630722037,-0.5808734644913993,0.10840912078696074,-1.4890297420601235,-0.9217878686054021,-0.841949405307442,-1.1790109210055038,-0.44815182728073877,-0.9037748924881824,-1.3072159248804145,-1.5881225072494798,-0.7629585739051552,-0.02927462569318917,-1.4464445975667846,-2.0679563755580483,-1.2652785324174338,-0.5497799294149268,-1.3001960770819048,-0.45924779578267,-0.5200422954588098,-2.384060824840116,-1.0082322854639967,-1.9518819404837369,-1.1976253375072978,0.1268430127796063,-1.8541327762313187,-1.487220567758474,-1.5932860001523828,-1.5550874344912902,-0.35499337333458714,-0.8752225312579465,-0.997084510695305,-0.48789993766784495,0.5135018751938177,-0.5773517383510043,0.23417799305857978,-0.4324032183989852,-1.455361307670379,-0.21155128813444946,-1.809602177981087,-0.32426607935717455,-1.2311006705183425,-0.6963139570375018,-0.45814325093337643,-0.6211628839163915,-0.8260777350094801,-0.08429890097250503,-1.2778043123943164,-1.723855037985254,-1.064080489918187,-1.45682260427024,-0.20227289769965728,-1.833094650202496,-1.0752808424056202,-0.331217264229552,-1.1430240090849078,-0.8007752814289547,-1.5924938090762901,-1.8917075147921651,-0.45241667506020977,-0.5996131982862651,-1.1207380368680422,-1.3599620192481976,-0.12687063713848634,-0.09069334963470588,-0.606382421834576,-1.274784273909077,-1.922171481693777,-0.5323501175695255,-0.7527657400524046,-1.2273464271791095,-1.221541804032468,-1.2654546074796342,-1.4202904872756803,-0.9910239583786321,-0.31610852266507394,-0.4645883385722762,-0.4507393165447694,-0.8812136205637948,-1.0708082622984973,-0.14386947646037684,-0.6055852731331017,-0.9678509094733606,-0.5877865667342037,-1.0642398317791568,-0.9666382566451738,-0.9320302146740319,-0.5359441832867944,-1.1035446527105834,-0.9237491350289262,-0.05001933526857982,-0.3984083840110025,-1.1759614699866652,-1.942836848176253,-0.8441904422278833,0.2331215457982151,-0.9592762081660619,-0.961367144666087,-1.3390213313143038,-0.3760062418463476,0.14215018250562417,-1.1751181897980745,-0.6969489643272052,-0.24844481509431066,-0.3626889146157966,-0.30787390827290306,-0.7566002147602289,-0.07258647820476372,-1.5581709882774488,0.386173063258063,-0.07183816232061746,-0.6289646979207015,-0.6335285203038962,-1.0324598001875525,-0.7441621541822308,0.10122836246329137,-1.5375098733718056,-1.5582240751011305,0.0978217124087356,-1.2739882479109685,-1.2289305111560185,-0.5707508274926087,-1.5684052389962826,-1.0843400774263794,-0.2518235965871985,-0.2254071625678577,-0.6989180453978728,-1.999386172063549,-1.226003764142183,-0.657617561721026,0.2899654751281444,-0.8469031706615184,-1.137908509238187,-1.4697877747405212,-0.4283560847182343,-2.1160371165121594,0.11893520809655489,-1.5255471820776474,-0.23430981722678246,-0.4218110502894875,-1.4102918213768172,-0.9577591344490812,0.4416848805765651,-0.40317114562891454,-0.7201127445710416,-1.154901920329747,-0.4030992838459526,-0.8987034851614919,-1.1283163853611369,-1.246795895195798,0.00402644200430613,-0.1693683966952036,-0.7263608031866726,-0.8241727667784494,0.09703130645342517,0.010599139685680381,-0.10633996253250921,-0.7814645230184973,-1.2153521259677484,0.9916459738130269,-0.09734015429800036,-0.7626373205543453,-0.30158051427345456,-1.1461313122155352,-0.04968022108049397,-0.45123407733762916, ...
