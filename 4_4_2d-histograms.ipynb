// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta9"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta9"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.github.io/Plotly.NET/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.github.io/Plotly.NET/img/badge-script.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.github.io/Plotly.NET/img/badge-notebook.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="9f2e9ab4-083f-47e8-9c58-4e19eca18a95" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_9f2e9ab4083f47e89c584e19eca18a95 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.8171039321986806,-2.6960760995032875,-0.6421918709647785,-0.5409668917541601,-0.8478362189411636,-0.3859586798741652,-0.6334515308938048,-0.23730780245852479,-0.9599676869773957,-0.9252800520038623,-1.504265629223478,-0.42521129625916676,-1.554671972687824,-0.8559310664058444,-0.5870080248430838,-2.142500776822313,-0.5927857908083534,-1.2581057919697862,-1.6366445103049796,-2.027871742210046,-1.030986630406862,-1.7442416628545847,-0.3877881107388139,-0.6223397748388266,-0.16795018695974506,-1.0743902786269104,-1.0069336098293529,-0.9442213511444093,-0.12986826905567095,-1.252366951475243,-0.6214275079952418,-0.47709588585272655,-0.8057026766290251,-0.41970647818046125,0.07839185639989321,0.3459608846115316,-0.3952867325254228,-0.8596822733174012,-1.2696811206435579,-1.774867025146912,-0.4444151870185406,-0.4973312172594541,-0.17743136039915786,-1.7235109755154903,-1.8350297148226304,0.10120417182652752,-1.5566962607286654,-0.639350866876726,-1.2916231910194893,-0.35147565150977766,-0.5086177281896007,-0.201446577851203,-0.03180459474357811,-0.7565492014557424,-0.388112384642922,0.04267393477588277,-1.448512974708184,-0.5354361902275073,-1.1193394103443421,-1.1060776750618424,-0.008422956132211001,-0.616839548381771,-1.2340930559175298,-1.0966875217534486,-0.4984691096480496,-0.4738099964325206,-0.829880352790565,0.6235837977194274,-0.004030453688356306,-0.7776399758968877,-0.1883833077656636,-1.6918670065350532,0.24507493578668438,-0.6986887619979907,-1.0675200208235798,-0.6794432242855474,-0.7080404179120697,0.5055316493995228,-1.5124736498179958,-0.6804466456992571,-0.7842806515683166,-0.5686239943439719,-0.20729605531302997,-0.10975698805491363,0.5893352163215712,-0.7244565325594619,-1.471318711170358,-1.0972806699575883,-0.32991357134368005,-2.2865665468380243,-0.4848624545887596,-1.149272938157287,-0.9151989673430037,-1.0832774076040184,-0.2151928910067994,-0.2643475169282033,-0.5631005472417032,-1.0775187976784,-0.35553879845412295,-0.45324341467309104,-1.7817756460434548,-0.7213305065309278,0.5812585584498834,0.6696770018941959,-1.2250423017776555,-0.4226255958996372,-0.25931147835047963,-0.30619974320902027,-0.39118791389206137,-1.150833771880759,-0.0296869804619605,-0.5139858098381243,-1.4483672727939523,-1.521026695665981,-1.061944656251899,0.08877807166424878,-0.9715801843079673,-0.692795393210953,-0.750235753582475,-1.577843447205387,-0.9742551035071395,-0.4153817223002959,-1.5960471780511796,-0.7753651605211276,-0.6375507351376486,-1.0188556926444878,-1.088747339519682,-0.8610739993108678,-0.6795728966541844,-0.5780682591290645,-0.17626755433966268,0.5865530065303739,0.4269615892300316,-0.5569300647645735,0.8210272331058537,-1.383419620593323,-0.2027288722590445,-1.1546698349622004,0.03719849492008753,-0.3307183810173583,-0.27964780656168287,-0.2591022418418484,-1.4046409283035222,-0.919844806162256,-0.7658905384881093,-1.0822188923299931,-1.0977668669124783,-1.0443428366883838,-1.0532115542412785,0.29538618418037477,-0.130986380946488,-0.40203839458505863,-0.5254474954811768,-0.9938004715168693,-1.5726652577093343,-1.1764738265471046,-0.27987866855451843,-0.04631640295209882,-1.2781841150072688,-0.09037154984101875,-0.0846533073013751,-1.1817033002418214,0.01651692994802567,-0.18619656084753466,-0.1622248302925749,0.5789721549173751,-0.7018972198189849,-0.41269897375815423,-0.4969334849445096,-0.7477645775894812,-0.2324537957066729,0.48589819739161777,0.05413758243588229,-0.652782387217613,-0.83327395625 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="e0ed6212-4f94-4489-bfa2-b0f929a3e169" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_e0ed62124f944489bfa2b0f929a3e169 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.8171039321986806,-2.6960760995032875,-0.6421918709647785,-0.5409668917541601,-0.8478362189411636,-0.3859586798741652,-0.6334515308938048,-0.23730780245852479,-0.9599676869773957,-0.9252800520038623,-1.504265629223478,-0.42521129625916676,-1.554671972687824,-0.8559310664058444,-0.5870080248430838,-2.142500776822313,-0.5927857908083534,-1.2581057919697862,-1.6366445103049796,-2.027871742210046,-1.030986630406862,-1.7442416628545847,-0.3877881107388139,-0.6223397748388266,-0.16795018695974506,-1.0743902786269104,-1.0069336098293529,-0.9442213511444093,-0.12986826905567095,-1.252366951475243,-0.6214275079952418,-0.47709588585272655,-0.8057026766290251,-0.41970647818046125,0.07839185639989321,0.3459608846115316,-0.3952867325254228,-0.8596822733174012,-1.2696811206435579,-1.774867025146912,-0.4444151870185406,-0.4973312172594541,-0.17743136039915786,-1.7235109755154903,-1.8350297148226304,0.10120417182652752,-1.5566962607286654,-0.639350866876726,-1.2916231910194893,-0.35147565150977766,-0.5086177281896007,-0.201446577851203,-0.03180459474357811,-0.7565492014557424,-0.388112384642922,0.04267393477588277,-1.448512974708184,-0.5354361902275073,-1.1193394103443421,-1.1060776750618424,-0.008422956132211001,-0.616839548381771,-1.2340930559175298,-1.0966875217534486,-0.4984691096480496,-0.4738099964325206,-0.829880352790565,0.6235837977194274,-0.004030453688356306,-0.7776399758968877,-0.1883833077656636,-1.6918670065350532,0.24507493578668438,-0.6986887619979907,-1.0675200208235798,-0.6794432242855474,-0.7080404179120697,0.5055316493995228,-1.5124736498179958,-0.6804466456992571,-0.7842806515683166,-0.5686239943439719,-0.20729605531302997,-0.10975698805491363,0.5893352163215712,-0.7244565325594619,-1.471318711170358,-1.0972806699575883,-0.32991357134368005,-2.2865665468380243,-0.4848624545887596,-1.149272938157287,-0.9151989673430037,-1.0832774076040184,-0.2151928910067994,-0.2643475169282033,-0.5631005472417032,-1.0775187976784,-0.35553879845412295,-0.45324341467309104,-1.7817756460434548,-0.7213305065309278,0.5812585584498834,0.6696770018941959,-1.2250423017776555,-0.4226255958996372,-0.25931147835047963,-0.30619974320902027,-0.39118791389206137,-1.150833771880759,-0.0296869804619605,-0.5139858098381243,-1.4483672727939523,-1.521026695665981,-1.061944656251899,0.08877807166424878,-0.9715801843079673,-0.692795393210953,-0.750235753582475,-1.577843447205387,-0.9742551035071395,-0.4153817223002959,-1.5960471780511796,-0.7753651605211276,-0.6375507351376486,-1.0188556926444878,-1.088747339519682,-0.8610739993108678,-0.6795728966541844,-0.5780682591290645,-0.17626755433966268,0.5865530065303739,0.4269615892300316,-0.5569300647645735,0.8210272331058537,-1.383419620593323,-0.2027288722590445,-1.1546698349622004,0.03719849492008753,-0.3307183810173583,-0.27964780656168287,-0.2591022418418484,-1.4046409283035222,-0.919844806162256,-0.7658905384881093,-1.0822188923299931,-1.0977668669124783,-1.0443428366883838,-1.0532115542412785,0.29538618418037477,-0.130986380946488,-0.40203839458505863,-0.5254474954811768,-0.9938004715168693,-1.5726652577093343,-1.1764738265471046,-0.27987866855451843,-0.04631640295209882,-1.2781841150072688,-0.09037154984101875,-0.0846533073013751,-1.1817033002418214,0.01651692994802567,-0.18619656084753466,-0.1622248302925749,0.5789721549173751,-0.7018972198189849,-0.41269897375815423,-0.4969334849445096,-0.7477645775894812,-0.2324537957066729,0.48589819739161777,0.05413758243588229,-0.652782387217613,-0.8332739562597882,0 ...
