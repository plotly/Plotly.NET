// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta9"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta9"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="4a57d112-ecfa-4437-b4e4-2e2f4ffcaddb" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_4a57d112ecfa4437b4e42e2f4ffcaddb = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.6218021440264705,-1.3164743543662527,-1.3359891163329358,-0.5464335521952459,-0.28329153887584413,-0.9329438235116168,0.4085747880281795,-0.8320235719008273,-1.247500635750993,-1.504780417508151,-1.4109454438295979,-0.931834708948216,-1.324539425819772,-0.8923527333903645,-0.6006122803184153,-1.5143626615526764,-0.419904825075631,-1.1802281294955859,0.4707769313898291,-1.6047344069685487,-1.4706381181221029,-0.3074536200286876,-0.9425741520421544,-1.1504925645279551,-0.9173151266141522,-0.349052619763321,-1.3742989463748945,-0.7027319020985408,-1.2877410677714514,-2.3408303892918956,-0.5807209693765722,-0.6817916279070793,-0.16026447128608312,-1.1090970860843898,-0.7493755887480736,-0.44039492389226526,-1.5904823347092742,-1.812017525082943,-0.9719522403542861,-0.5199977937566547,-1.6748175847709696,-1.4905394653992206,-2.281802279906132,-0.24560111953362818,-1.035069134092733,-0.462955443009197,-0.7233031702947672,-0.4102955432597526,-1.4549229912266188,-0.8609658682604362,-1.3038484819333307,-1.0812199512491372,-0.7580293843872602,-1.1029206766409698,-0.8296776045981376,-0.8121774112337561,-1.5605462994756745,-1.0765822653568495,-0.37486954529234606,-0.18431181253657491,-0.7444822301389636,-1.2279369723255424,-0.5507693075212541,-0.3434614716856302,-1.4995921764891893,-0.9008964619552319,-0.7124798618568057,-1.1709877265566284,-0.874875323972903,-0.7319687250906428,-0.6882636215309964,-0.4994950083637947,-0.6920811791861825,-1.2549055389324937,-1.5390920881656016,-0.3494855565340862,-0.5832228194319111,-0.03180512651175815,-0.503398878220692,-0.8785614315138115,-0.7749837126782915,0.3273483520139082,-1.2505601560633584,-1.435935957665774,-0.9446398629184718,-0.5798536790730997,-0.6814187295369925,-0.4929666184616103,-0.5637944340467048,-0.16010694834309536,-1.0993378174339024,-0.9349136921312504,-0.8437863667505511,-1.0001259391833122,-0.5081899800516487,-1.8127177937404149,-1.5970447580397318,-1.571042665163932,-1.140920661147383,-0.27098014843829255,-1.5187570674133175,-0.7346732343565765,-1.218237975820365,-1.5538628126973135,0.016466248988004306,-0.250654822490166,0.2380376848842628,-0.5654209917769386,0.012009367696756756,-0.4047519875391228,0.11831748320170099,-1.1724801863004919,-1.0492676780302537,-0.8020425711261544,-0.44787926445606896,-0.5662266122301388,-1.1476968865098476,-0.2597201992208109,-0.43880176224207496,-0.2886337829433469,-0.3713037200493417,-0.7574011324131009,-1.2036280351486628,-0.21613765298733523,-0.5796952926556453,-1.3687303198643663,-0.17149397058678034,-0.547347787852086,-0.29525055915241366,-1.6056367171663561,0.1602965167799002,-0.7416564097818074,-0.49656277812818095,-0.9948826244292215,-1.1143786945123146,0.302011351989552,-1.3427613455856626,0.32446725619250105,-1.0146370030705707,-1.1187563022553664,-2.005984985028308,-1.3141364499877957,-0.9650806839072491,-0.7600600237363087,-1.2348530029257563,-1.212453829867048,-0.5855745465428057,0.03086008513070493,-1.4757621197378439,-0.8842962023979926,0.6242637626738939,-0.9402935413038767,0.1526145461039049,-0.996001915183813,-0.9339792805742135,-0.5499584320998073,-0.15155232222716086,-0.4019644077656477,0.6776659090706957,-0.499023063264727,0.18894463773239611,-0.6315060634552603,-0.798580030073957,-0.26533023510920517,-0.33247465344615534,-0.08226694031525561,-1.283461620692119,-0.13225240311965575,0.32254583163486317,-0.849770686892165,-1.1851873325290927,-0.723424471490844,0.0772731441911545,-0.1418747910008643,-0.8673985794740907 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="0bd4e760-7c4f-40bd-8106-ec2c40a978fa" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_0bd4e7607c4f40bd8106ec2c40a978fa = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.6218021440264705,-1.3164743543662527,-1.3359891163329358,-0.5464335521952459,-0.28329153887584413,-0.9329438235116168,0.4085747880281795,-0.8320235719008273,-1.247500635750993,-1.504780417508151,-1.4109454438295979,-0.931834708948216,-1.324539425819772,-0.8923527333903645,-0.6006122803184153,-1.5143626615526764,-0.419904825075631,-1.1802281294955859,0.4707769313898291,-1.6047344069685487,-1.4706381181221029,-0.3074536200286876,-0.9425741520421544,-1.1504925645279551,-0.9173151266141522,-0.349052619763321,-1.3742989463748945,-0.7027319020985408,-1.2877410677714514,-2.3408303892918956,-0.5807209693765722,-0.6817916279070793,-0.16026447128608312,-1.1090970860843898,-0.7493755887480736,-0.44039492389226526,-1.5904823347092742,-1.812017525082943,-0.9719522403542861,-0.5199977937566547,-1.6748175847709696,-1.4905394653992206,-2.281802279906132,-0.24560111953362818,-1.035069134092733,-0.462955443009197,-0.7233031702947672,-0.4102955432597526,-1.4549229912266188,-0.8609658682604362,-1.3038484819333307,-1.0812199512491372,-0.7580293843872602,-1.1029206766409698,-0.8296776045981376,-0.8121774112337561,-1.5605462994756745,-1.0765822653568495,-0.37486954529234606,-0.18431181253657491,-0.7444822301389636,-1.2279369723255424,-0.5507693075212541,-0.3434614716856302,-1.4995921764891893,-0.9008964619552319,-0.7124798618568057,-1.1709877265566284,-0.874875323972903,-0.7319687250906428,-0.6882636215309964,-0.4994950083637947,-0.6920811791861825,-1.2549055389324937,-1.5390920881656016,-0.3494855565340862,-0.5832228194319111,-0.03180512651175815,-0.503398878220692,-0.8785614315138115,-0.7749837126782915,0.3273483520139082,-1.2505601560633584,-1.435935957665774,-0.9446398629184718,-0.5798536790730997,-0.6814187295369925,-0.4929666184616103,-0.5637944340467048,-0.16010694834309536,-1.0993378174339024,-0.9349136921312504,-0.8437863667505511,-1.0001259391833122,-0.5081899800516487,-1.8127177937404149,-1.5970447580397318,-1.571042665163932,-1.140920661147383,-0.27098014843829255,-1.5187570674133175,-0.7346732343565765,-1.218237975820365,-1.5538628126973135,0.016466248988004306,-0.250654822490166,0.2380376848842628,-0.5654209917769386,0.012009367696756756,-0.4047519875391228,0.11831748320170099,-1.1724801863004919,-1.0492676780302537,-0.8020425711261544,-0.44787926445606896,-0.5662266122301388,-1.1476968865098476,-0.2597201992208109,-0.43880176224207496,-0.2886337829433469,-0.3713037200493417,-0.7574011324131009,-1.2036280351486628,-0.21613765298733523,-0.5796952926556453,-1.3687303198643663,-0.17149397058678034,-0.547347787852086,-0.29525055915241366,-1.6056367171663561,0.1602965167799002,-0.7416564097818074,-0.49656277812818095,-0.9948826244292215,-1.1143786945123146,0.302011351989552,-1.3427613455856626,0.32446725619250105,-1.0146370030705707,-1.1187563022553664,-2.005984985028308,-1.3141364499877957,-0.9650806839072491,-0.7600600237363087,-1.2348530029257563,-1.212453829867048,-0.5855745465428057,0.03086008513070493,-1.4757621197378439,-0.8842962023979926,0.6242637626738939,-0.9402935413038767,0.1526145461039049,-0.996001915183813,-0.9339792805742135,-0.5499584320998073,-0.15155232222716086,-0.4019644077656477,0.6776659090706957,-0.499023063264727,0.18894463773239611,-0.6315060634552603,-0.798580030073957,-0.26533023510920517,-0.33247465344615534,-0.08226694031525561,-1.283461620692119,-0.13225240311965575,0.32254583163486317,-0.849770686892165,-1.1851873325290927,-0.723424471490844,0.0772731441911545,-0.1418747910008643,-0.8673985794740907,-0.749 ...
