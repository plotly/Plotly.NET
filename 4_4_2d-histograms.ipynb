// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.5"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.5"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="366a8939-2881-424c-a420-ea717734e70b" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_366a89392881424ca420ea717734e70b = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.1295097986834336,-0.14502110324356177,-1.215029122179997,-0.5422126253055899,-0.36565997278998186,-1.2325630554101938,-0.43851136782595734,-1.3696493181045788,-1.871232049184101,-0.6733135830476296,-1.2927963670917673,-1.3773879501244555,-1.112222505365408,-0.36384322835560134,-1.514460960816466,-0.24177215192113455,-1.6759744398342045,0.10391610503932192,-0.6050710203853874,-0.9335562766382146,-2.4438156970350926,-1.2589023301416444,-1.0645796002485512,-1.507885226382488,-0.997487305402356,-0.3884042720296996,-1.6310493997542688,-0.057753126604145666,-1.0442271369906841,-0.5972605097852489,-1.6194030442592844,-0.06008458019832408,-0.2502985915846293,-0.8724794457464659,-1.7007353435358668,-0.5089202267044135,-1.547440203415471,-1.4738703004752427,-0.6612560615256843,-1.4590311412597263,-0.036398052396129366,-1.2283336480032712,-0.8896275305880343,0.025791443402107705,-0.6123841177113839,-1.5189337683660793,0.017389592033456025,-0.07863196082527579,0.026339684630