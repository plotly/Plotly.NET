// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta.10"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta.10"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="bd13011a-c217-480e-be06-bde03484ce13" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_bd13011ac217480ebe06bde03484ce13 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.1246747167179512,-0.7408780948473361,0.6097499831093259,-1.2649220272560158,-0.9703578024270841,-0.9392540980670653,-0.8579939236097516,-0.696597313259256,-0.27118968158034995,-2.3646316569347974,-0.6143012632365109,-0.18637467548518216,-0.9999892786919979,-0.8535061208402813,-1.051310527984222,-0.693701751435553,-1.475283758817023,-0.4112281936004568,-0.5335736558615036,-0.7351965042597141,-1.2218082409618214,-0.6443801179634299,-1.2412900023879962,-0.0383632408382224,-1.7139068558285717,-0.7988554718722553,-0.3266448251371442,0.23657525303211768,-0.5418242899809425,0.2542201735430284,-2.7617248352607073,-0.8354145169942122,-1.0163160111695917,-0.8392656112808502,-0.7410612797842651,-1.8503806029358225,0.08642664351472462,-0.16268914707851978,-0.6378175264439272,-1.139556148607146,-0.7959477266071838,-0.2062242772320938,-0.8573570167173376,-0.9678492264617689,-1.0946298985013339,-0.6955153658520667,0.741387170826377,-0.04871213604311109,-1.2735103364875568,-1.0259552065196154,-0.2621516153103025,-0.1322053976160621,-1.2766739472043822,0.42433910457327495,-1.2739252529929088,-1.157636620082004,-1.175939121733233,-1.3835344851827471,-1.8257876101377544,-0.5247071097123717,-0.4875643898152461,-0.15264429090491916,-0.930461840734497,0.46604905651527406,-1.2644724446466922,-1.3053086365114992,-0.7176913350293543,-0.8052816697419586,-1.5595860806195105,-1.2977984095528408,-0.06187752283574943,-0.4193878179264995,-0.8327249037953717,-1.675815564534569,-0.27703883665087037,-1.2807890314583295,-0.7624953844343412,-1.2641583524412636,-0.38395553767415974,-1.982510978271912,-0.6727011940516023,-1.407863081279584,-1.0125977927584509,0.16991457214082595,-0.7631875192653567,-1.1848266714717988,-0.21641639568762971,-2.350421940785015,-1.531210784077444,-0.634752851368111,-1.0822841280584719,-1.1574904478024166,-0.5561098340774937,-0.46491985356111004,-0.06435590292081816,-0.6379640063986102,-0.8235372042369443,-1.2504781149239694,-0.4696424661040365,-1.6676695857210495,-0.7905329504554285,-1.5120850751316937,-1.6797377172661494,-0.8175121100912003,0.2783484645939923,-0.8334330141819921,-0.2900098378874517,-0.8858761867718662,-0.6945768319450671,-1.0220933471571827,-0.07549452559866432,-0.7610605879747856,-0.3395039295259136,-0.12812193135787409,0.09589309794236267,-0.7419415706479597,-0.06469329537320534,-1.1830620722078975,-0.7301419299093393,-1.0144493973526854,-0.5557156274534707,-0.09008818730297197,0.2479912235975521,-0.14913249607215795,0.5343431484994928,-1.5808285645578173,-1.3576609188873219,-0.532663069865129,-0.7268035094849874,-0.4519101086185332,-0.5929866548818654,-0.6693088952791031,-0.10078789843370417,-0.7402815909792115,-1.3562214382611466,-0.741903531969397,-0.5244602682443543,-0.7778769312668112,-0.7428016677496485,-1.4395256770082927,-1.7912299089001043,-1.3535089181347644,-1.6009340158384802,-0.990738378138035,-1.1426412029602986,-0.16471461728548392,-0.9300456389904559,-1.3220645652660203,-0.7902468162730493,0.1557678054698325,-0.9778977444047419,-0.6341152440045139,-0.46812612836602274,-0.48586312587822444,-0.4382465236158634,-1.1738583118075916,-1.106776801160534,-0.8776125094429885,-0.09471502354499195,-0.14172505767449955,0.1847035968244981,0.3026205189475494,-0.8955640830547145,0.3085945556305729,-1.1814867518623666,-1.0845581835926787,-0.4245573500210109,-1.2940623905212392,0.2666831609936039,-1.5822479164052798,-0.5521791588355234,-0.5231305883548166,-0.18370859474735252,0.13076646262535985,-0.64849488 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="9a788ffa-0ebf-4e6a-a6a6-e32277098a7d" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_9a788ffa0ebf4e6aa6a6e32277098a7d = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.1246747167179512,-0.7408780948473361,0.6097499831093259,-1.2649220272560158,-0.9703578024270841,-0.9392540980670653,-0.8579939236097516,-0.696597313259256,-0.27118968158034995,-2.3646316569347974,-0.6143012632365109,-0.18637467548518216,-0.9999892786919979,-0.8535061208402813,-1.051310527984222,-0.693701751435553,-1.475283758817023,-0.4112281936004568,-0.5335736558615036,-0.7351965042597141,-1.2218082409618214,-0.6443801179634299,-1.2412900023879962,-0.0383632408382224,-1.7139068558285717,-0.7988554718722553,-0.3266448251371442,0.23657525303211768,-0.5418242899809425,0.2542201735430284,-2.7617248352607073,-0.8354145169942122,-1.0163160111695917,-0.8392656112808502,-0.7410612797842651,-1.8503806029358225,0.08642664351472462,-0.16268914707851978,-0.6378175264439272,-1.139556148607146,-0.7959477266071838,-0.2062242772320938,-0.8573570167173376,-0.9678492264617689,-1.0946298985013339,-0.6955153658520667,0.741387170826377,-0.04871213604311109,-1.2735103364875568,-1.0259552065196154,-0.2621516153103025,-0.1322053976160621,-1.2766739472043822,0.42433910457327495,-1.2739252529929088,-1.157636620082004,-1.175939121733233,-1.3835344851827471,-1.8257876101377544,-0.5247071097123717,-0.4875643898152461,-0.15264429090491916,-0.930461840734497,0.46604905651527406,-1.2644724446466922,-1.3053086365114992,-0.7176913350293543,-0.8052816697419586,-1.5595860806195105,-1.2977984095528408,-0.06187752283574943,-0.4193878179264995,-0.8327249037953717,-1.675815564534569,-0.27703883665087037,-1.2807890314583295,-0.7624953844343412,-1.2641583524412636,-0.38395553767415974,-1.982510978271912,-0.6727011940516023,-1.407863081279584,-1.0125977927584509,0.16991457214082595,-0.7631875192653567,-1.1848266714717988,-0.21641639568762971,-2.350421940785015,-1.531210784077444,-0.634752851368111,-1.0822841280584719,-1.1574904478024166,-0.5561098340774937,-0.46491985356111004,-0.06435590292081816,-0.6379640063986102,-0.8235372042369443,-1.2504781149239694,-0.4696424661040365,-1.6676695857210495,-0.7905329504554285,-1.5120850751316937,-1.6797377172661494,-0.8175121100912003,0.2783484645939923,-0.8334330141819921,-0.2900098378874517,-0.8858761867718662,-0.6945768319450671,-1.0220933471571827,-0.07549452559866432,-0.7610605879747856,-0.3395039295259136,-0.12812193135787409,0.09589309794236267,-0.7419415706479597,-0.06469329537320534,-1.1830620722078975,-0.7301419299093393,-1.0144493973526854,-0.5557156274534707,-0.09008818730297197,0.2479912235975521,-0.14913249607215795,0.5343431484994928,-1.5808285645578173,-1.3576609188873219,-0.532663069865129,-0.7268035094849874,-0.4519101086185332,-0.5929866548818654,-0.6693088952791031,-0.10078789843370417,-0.7402815909792115,-1.3562214382611466,-0.741903531969397,-0.5244602682443543,-0.7778769312668112,-0.7428016677496485,-1.4395256770082927,-1.7912299089001043,-1.3535089181347644,-1.6009340158384802,-0.990738378138035,-1.1426412029602986,-0.16471461728548392,-0.9300456389904559,-1.3220645652660203,-0.7902468162730493,0.1557678054698325,-0.9778977444047419,-0.6341152440045139,-0.46812612836602274,-0.48586312587822444,-0.4382465236158634,-1.1738583118075916,-1.106776801160534,-0.8776125094429885,-0.09471502354499195,-0.14172505767449955,0.1847035968244981,0.3026205189475494,-0.8955640830547145,0.3085945556305729,-1.1814867518623666,-1.0845581835926787,-0.4245573500210109,-1.2940623905212392,0.2666831609936039,-1.5822479164052798,-0.5521791588355234,-0.5231305883548166,-0.18370859474735252,0.13076646262535985,-0.648494885127320 ...
