// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.7"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.7"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.combine

// %%
histogramContour
// Out:
// <div id="d026c511-24e7-4ea3-a495-126566edb4cf" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_d026c51124e74ea3a495126566edb4cf = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-2.956736019079414,-0.7046325223945729,-2.319453911356423,-1.01586153876439,-1.1165407075855125,-1.5333605092810298,-1.093996443876313,-1.1099651991963446,-0.4544826932249897,-0.790295449294729,-0.27582169521329547,-1.3327577757555191,-0.5713500183404188,-0.1231349960563991,-0.41074254462627613,-1.212684015238228,-1.341646567118184,-0.28809299136419897,-0.32812462776835405,-0.3688762842846828,-1.2927221804254825,-1.0831073799030877,-1.260967357526744,-1.7190187959201246,-0.870962823600138,-0.48591586513016566,0.3905715696064783,-0.06024146724531443,-0.6155799153695163,-0.10677277492993742,-0.5612264297690721,-1.0723546506743074,-1.352104849102291,-0.667936206865112,-0.4820268116873188,-1.4614478941429554,-0.38425645447909507,-0.6544067784530461,-1.0063678115025474,-1.6512328660857116,-0.5819046119543899,-0.5621128285732027,-0.6309019166085503,-0.7271427306975251,0.523762405386372,-0.9880517901601245,-1.2042048525392146,-0.5778662779037451,0.28649302319695336,-1.7280077344899325