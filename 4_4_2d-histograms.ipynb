// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-beta9"
#r "nuget: Plotly.NET.Interactive, 2.0.0-beta9"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.github.io/Plotly.NET/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.github.io/Plotly.NET/img/badge-script.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.github.io/Plotly.NET/img/badge-notebook.svg)](https://plotly.github.io/Plotly.NET/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="79fc7753-2b6f-4070-9d6d-1e009c62615e" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_79fc77532b6f40709d6d1e009c62615e = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.2096386610404841,-1.0197005141180784,-0.26199315802919565,-0.32901139155787795,-1.1022201921000603,-0.9016793894887201,-0.4395459533037993,-1.0864636466156925,-2.061888164912274,-0.8101946935691953,-1.2448923513081263,-0.9865246971322659,-1.2049874767880695,-1.831175705270884,-1.0349048936719067,-1.1568073996362616,-1.5380771244139082,-1.7985407734620353,-1.082458135650771,0.5106890222186483,-0.497952901981143,-0.18023328472118783,-1.857937184536944,-0.5143504275610611,0.2247246631456189,-2.2816421672666114,-0.9012282759005171,-1.875404397805352,-0.8788451440207872,-1.7101041799136105,-0.6853453854864763,-0.5737463133084759,-1.3549866896270966,-0.24470305514276458,-0.5149854585191638,-0.5076335918121472,-1.5991501564695172,-0.5176131096391134,-0.562838923676588,-0.7180169221399006,-1.1670915727599993,-1.6292064358997875,-0.357290852491042,-1.051094427228689,-1.9508359067156658,0.2531216295920782,-0.24207473998056728,-1.6772544425343394,-1.416627502139387,-1.3486382293282442,-2.1775265578601055,-1.2046382811028744,0.7757534195408136,-2.0369599415370896,-1.0684559221272902,-0.7717066232430979,-0.6706404009625406,-0.3425954473503942,-1.6020384168222606,-0.7525917867189091,-0.7955096684469368,-1.302904197499629,-0.6092407642832214,0.28386761149295137,-0.803226641368714,-0.11553031668801705,-0.8042580317805375,-0.8534492717424589,-0.42779371342635536,-0.8231411745823421,-1.6916594056228496,-1.3736557155201337,-0.6139341694679672,-0.3860532200955995,-0.5858438105438804,-1.2000629723926841,-1.1085939980837254,0.45551264104190103,-0.9650525880345449,-1.2035840169953587,-1.1103344732801423,-0.25644269850768675,-0.5128596336900644,-0.20392697269029625,-1.2446821445140692,-0.158191217231464,0.29898856020847775,-0.6101678036682814,-0.24020683689642264,-0.4377345518728644,-1.7417165740465688,-1.490404060822518,-1.3700656638198403,-1.7909740592488663,-0.6628407318986401,-0.4783293966233784,-1.263140846957444,-0.8014937898657714,-0.07470460648924093,-0.5583019475719109,-0.7702566575636669,-1.916554049354626,-0.8262677627389667,-0.9567687439402637,1.6327051525595646,0.752069915716928,-0.2909954588693807,-0.011517474815246342,-1.252997622324405,-1.219718423652094,-0.7216977287616476,-0.9235716274741579,-1.0825417020261838,-0.032534355247515245,-1.017637490434265,-0.31290357249135153,-0.898645951104839,-0.42517262849036525,-0.9480497489033248,-1.3183257134005055,-1.811853331605978,0.15225675505117864,-0.0033483034697340264,-0.29759187058539993,-0.06413867106215643,-0.6435613184602261,-0.4342401514582195,-0.6830216529260504,-1.8712087717647292,-0.7083959780685979,-0.42094480842206267,0.40284706243479396,-2.1841292113032917,-0.8671651061304078,-0.6548455350431784,-0.7311509893602367,-0.38549616109897933,-0.6093860260697727,-1.1434918219029306,-0.09651370219613864,-1.689858744233806,-0.27883715410383797,-0.5860223893104127,-0.6920635079769427,-0.8994606794977467,-0.25742657643334077,-0.8058049244275405,-0.5741641529729642,-0.40933818922954246,-0.8811466812450437,0.6046033326143817,-0.4557997929800987,-0.157116735248359,-0.19713472382722957,-0.10004608756305633,-1.666453006709793,-0.8312547376629957,-0.5181014743268803,-0.5639669952547863,-0.09288739028074716,-0.5778216276136084,-1.0253274424502732,-0.6728531120934332,-1.580843804823605,-1.4382007971204345,-0.6971422192810499,-1.1234742545134309,-1.0964081720138665,-1.119084242739361,-0.211503650797583,-1.24006279899208,0.08225431768443137,-0.04019354020525706,0.003088350034323728,-0.07836 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="1c7b98d3-c0d1-445b-a497-598dd9538bce" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_1c7b98d3c0d1445ba497598dd9538bce = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.2096386610404841,-1.0197005141180784,-0.26199315802919565,-0.32901139155787795,-1.1022201921000603,-0.9016793894887201,-0.4395459533037993,-1.0864636466156925,-2.061888164912274,-0.8101946935691953,-1.2448923513081263,-0.9865246971322659,-1.2049874767880695,-1.831175705270884,-1.0349048936719067,-1.1568073996362616,-1.5380771244139082,-1.7985407734620353,-1.082458135650771,0.5106890222186483,-0.497952901981143,-0.18023328472118783,-1.857937184536944,-0.5143504275610611,0.2247246631456189,-2.2816421672666114,-0.9012282759005171,-1.875404397805352,-0.8788451440207872,-1.7101041799136105,-0.6853453854864763,-0.5737463133084759,-1.3549866896270966,-0.24470305514276458,-0.5149854585191638,-0.5076335918121472,-1.5991501564695172,-0.5176131096391134,-0.562838923676588,-0.7180169221399006,-1.1670915727599993,-1.6292064358997875,-0.357290852491042,-1.051094427228689,-1.9508359067156658,0.2531216295920782,-0.24207473998056728,-1.6772544425343394,-1.416627502139387,-1.3486382293282442,-2.1775265578601055,-1.2046382811028744,0.7757534195408136,-2.0369599415370896,-1.0684559221272902,-0.7717066232430979,-0.6706404009625406,-0.3425954473503942,-1.6020384168222606,-0.7525917867189091,-0.7955096684469368,-1.302904197499629,-0.6092407642832214,0.28386761149295137,-0.803226641368714,-0.11553031668801705,-0.8042580317805375,-0.8534492717424589,-0.42779371342635536,-0.8231411745823421,-1.6916594056228496,-1.3736557155201337,-0.6139341694679672,-0.3860532200955995,-0.5858438105438804,-1.2000629723926841,-1.1085939980837254,0.45551264104190103,-0.9650525880345449,-1.2035840169953587,-1.1103344732801423,-0.25644269850768675,-0.5128596336900644,-0.20392697269029625,-1.2446821445140692,-0.158191217231464,0.29898856020847775,-0.6101678036682814,-0.24020683689642264,-0.4377345518728644,-1.7417165740465688,-1.490404060822518,-1.3700656638198403,-1.7909740592488663,-0.6628407318986401,-0.4783293966233784,-1.263140846957444,-0.8014937898657714,-0.07470460648924093,-0.5583019475719109,-0.7702566575636669,-1.916554049354626,-0.8262677627389667,-0.9567687439402637,1.6327051525595646,0.752069915716928,-0.2909954588693807,-0.011517474815246342,-1.252997622324405,-1.219718423652094,-0.7216977287616476,-0.9235716274741579,-1.0825417020261838,-0.032534355247515245,-1.017637490434265,-0.31290357249135153,-0.898645951104839,-0.42517262849036525,-0.9480497489033248,-1.3183257134005055,-1.811853331605978,0.15225675505117864,-0.0033483034697340264,-0.29759187058539993,-0.06413867106215643,-0.6435613184602261,-0.4342401514582195,-0.6830216529260504,-1.8712087717647292,-0.7083959780685979,-0.42094480842206267,0.40284706243479396,-2.1841292113032917,-0.8671651061304078,-0.6548455350431784,-0.7311509893602367,-0.38549616109897933,-0.6093860260697727,-1.1434918219029306,-0.09651370219613864,-1.689858744233806,-0.27883715410383797,-0.5860223893104127,-0.6920635079769427,-0.8994606794977467,-0.25742657643334077,-0.8058049244275405,-0.5741641529729642,-0.40933818922954246,-0.8811466812450437,0.6046033326143817,-0.4557997929800987,-0.157116735248359,-0.19713472382722957,-0.10004608756305633,-1.666453006709793,-0.8312547376629957,-0.5181014743268803,-0.5639669952547863,-0.09288739028074716,-0.5778216276136084,-1.0253274424502732,-0.6728531120934332,-1.580843804823605,-1.4382007971204345,-0.6971422192810499,-1.1234742545134309,-1.0964081720138665,-1.119084242739361,-0.211503650797583,-1.24006279899208,0.08225431768443137,-0.04019354020525706,0.003088350034323728,-0.078366524869 ...
