// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.1"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.1"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="fe882bf7-28bf-4ca8-bfb9-725a930128ef" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_fe882bf728bf4ca8bfb9725a930128ef = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.430244031528374,-0.7380547418493584,-1.1459301359229144,-0.6453425707974065,-1.288655080804947,-1.533053808282412,-0.41076072595682145,-0.6438679534538554,-1.732193534422898,-1.1078222603615273,-0.8568338974493189,-0.8652684064454947,-1.1032525151158916,-1.100238727253601,-0.7472817458539125,-0.5296819988535428,-2.0672343225393157,0.14721120164214818,-0.3761846784471722,-0.6948925390798494,-0.5019556895164567,-0.8706133021688274,-0.5131946964949159,-0.8429102996791717,-0.6065286771968632,-1.3465712847921447,-1.2236213697349032,-0.9803251030188954,0.1181407307598632,-1.6288585440353023,-0.46086978571292464,-1.056824454059695,-1.429676040869834,-0.7693913912904258,-1.579222875563137,-1.672824410877248,-1.7831385788673033,-1.3380772655473292,-1.367507137757322,-1.4533799104823393,-0.9899410509483895,-1.1980073924489727,-0.7750554683706448,-0.40463768710563813,-0.8402267835548315,-0.06750001005519923,-0.9767234998801604,-0.36018128994823007,-0.5141044778838897,-0.4550463504660886,-0.8753603075468616,0.5307654946803408,-1.5831173380589698,-0.22991869733089576,0.2661473450414513,-1.0206560291699127,-1.0661053247766634,0.3018336898450932,-0.21086337401923005,-2.029893870797528,-0.2035769550271005,-0.5561711591483882,-0.17801172156890366,-1.0571150861167946,-0.9148316440142387,-0.43513294238135,-1.418308447919984,-1.0566070704027732,-1.3562277261585216,-1.2599744268894542,-0.1374925897124687,-1.4221743335160413,-0.11451389370362253,-1.1481895359535221,-0.7713771513946068,-1.1163435238858346,-0.04487159624558856,-0.8026176263734245,0.529461007364962,-1.4590597923592372,-1.9637238580236689,-0.5413012052758586,-0.9132374501289546,-1.2791816017449311,-0.3572831977689927,-0.8808135335869579,-1.0092543127044313,-1.0947581280929104,-0.09913460275483366,-1.1104759119681733,-0.36728320388617675,-0.4014379981642838,-0.3550574642620705,-1.1064834647577246,-0.7131688952541,-0.7231552299583428,-0.9019879887365544,-1.2952018284112365,-0.8075679072797299,-0.12515890250898243,-0.6711798374570445,-0.3521264461741363,-0.2965961516448504,-1.2406709035853236,-0.8389816748001406,-0.6799855080841685,-0.7311283650594333,-0.8078750708593624,-0.2982529718451032,-0.048016265211018094,-0.054671423160060906,-0.008597920175446916,-1.6117119873932855,-1.431353193047801,-0.6860142731389868,-0.4773819632382791,-0.12768479253267573,0.2759414800015416,-0.6533008604256211,-0.8393448353473654,0.00670241625611967,-1.1850342895676225,-2.3854282090412386,-0.6262332986536416,-1.0063861671539127,0.23301156921734223,-0.19833610257214002,-1.022263045229297,-0.06511309788996866,-0.5015035292709535,0.3866629430729417,-0.7527470905797897,-0.10208405106297236,0.6172234968335057,-0.2118723117199499,-0.22789547580681646,-0.38807342716674775,-0.8690420523946626,-0.7984921078441276,-0.15603041633818515,-0.59731828831111,-1.85493099710558,-0.19544952989370112,-0.07998790801958156,-0.24196544326802377,-0.6812530887060357,-0.44173880640041735,-0.7166554946797855,-1.0945055674898951,-0.4851848675109022,-0.4366858606128483,-2.34220718790656,-0.138254238340687,-0.16154002202880818,-0.9181048422400733,-1.7882233537455714,-0.27132676185600846,-0.12684361159372254,-0.6303420601180632,-0.8610700956911768,0.479866071782289,-1.5053817678473336,0.20343584575234774,0.027105811897033094,-0.23219180892414037,-2.2569838290848705,-0.37361800584047067,-1.1656641986171679,-0.9775813912954915,-0.8295856672874371,-0.6093704111214201,-0.21797665334674826,-1.3101978475849783,-0.9081637367072684,-1.8 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="cf4a4c6a-9be9-456a-b3e1-3c02685210a9" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_cf4a4c6a9be9456ab3e13c02685210a9 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.430244031528374,-0.7380547418493584,-1.1459301359229144,-0.6453425707974065,-1.288655080804947,-1.533053808282412,-0.41076072595682145,-0.6438679534538554,-1.732193534422898,-1.1078222603615273,-0.8568338974493189,-0.8652684064454947,-1.1032525151158916,-1.100238727253601,-0.7472817458539125,-0.5296819988535428,-2.0672343225393157,0.14721120164214818,-0.3761846784471722,-0.6948925390798494,-0.5019556895164567,-0.8706133021688274,-0.5131946964949159,-0.8429102996791717,-0.6065286771968632,-1.3465712847921447,-1.2236213697349032,-0.9803251030188954,0.1181407307598632,-1.6288585440353023,-0.46086978571292464,-1.056824454059695,-1.429676040869834,-0.7693913912904258,-1.579222875563137,-1.672824410877248,-1.7831385788673033,-1.3380772655473292,-1.367507137757322,-1.4533799104823393,-0.9899410509483895,-1.1980073924489727,-0.7750554683706448,-0.40463768710563813,-0.8402267835548315,-0.06750001005519923,-0.9767234998801604,-0.36018128994823007,-0.5141044778838897,-0.4550463504660886,-0.8753603075468616,0.5307654946803408,-1.5831173380589698,-0.22991869733089576,0.2661473450414513,-1.0206560291699127,-1.0661053247766634,0.3018336898450932,-0.21086337401923005,-2.029893870797528,-0.2035769550271005,-0.5561711591483882,-0.17801172156890366,-1.0571150861167946,-0.9148316440142387,-0.43513294238135,-1.418308447919984,-1.0566070704027732,-1.3562277261585216,-1.2599744268894542,-0.1374925897124687,-1.4221743335160413,-0.11451389370362253,-1.1481895359535221,-0.7713771513946068,-1.1163435238858346,-0.04487159624558856,-0.8026176263734245,0.529461007364962,-1.4590597923592372,-1.9637238580236689,-0.5413012052758586,-0.9132374501289546,-1.2791816017449311,-0.3572831977689927,-0.8808135335869579,-1.0092543127044313,-1.0947581280929104,-0.09913460275483366,-1.1104759119681733,-0.36728320388617675,-0.4014379981642838,-0.3550574642620705,-1.1064834647577246,-0.7131688952541,-0.7231552299583428,-0.9019879887365544,-1.2952018284112365,-0.8075679072797299,-0.12515890250898243,-0.6711798374570445,-0.3521264461741363,-0.2965961516448504,-1.2406709035853236,-0.8389816748001406,-0.6799855080841685,-0.7311283650594333,-0.8078750708593624,-0.2982529718451032,-0.048016265211018094,-0.054671423160060906,-0.008597920175446916,-1.6117119873932855,-1.431353193047801,-0.6860142731389868,-0.4773819632382791,-0.12768479253267573,0.2759414800015416,-0.6533008604256211,-0.8393448353473654,0.00670241625611967,-1.1850342895676225,-2.3854282090412386,-0.6262332986536416,-1.0063861671539127,0.23301156921734223,-0.19833610257214002,-1.022263045229297,-0.06511309788996866,-0.5015035292709535,0.3866629430729417,-0.7527470905797897,-0.10208405106297236,0.6172234968335057,-0.2118723117199499,-0.22789547580681646,-0.38807342716674775,-0.8690420523946626,-0.7984921078441276,-0.15603041633818515,-0.59731828831111,-1.85493099710558,-0.19544952989370112,-0.07998790801958156,-0.24196544326802377,-0.6812530887060357,-0.44173880640041735,-0.7166554946797855,-1.0945055674898951,-0.4851848675109022,-0.4366858606128483,-2.34220718790656,-0.138254238340687,-0.16154002202880818,-0.9181048422400733,-1.7882233537455714,-0.27132676185600846,-0.12684361159372254,-0.6303420601180632,-0.8610700956911768,0.479866071782289,-1.5053817678473336,0.20343584575234774,0.027105811897033094,-0.23219180892414037,-2.2569838290848705,-0.37361800584047067,-1.1656641986171679,-0.9775813912954915,-0.8295856672874371,-0.6093704111214201,-0.21797665334674826,-1.3101978475849783,-0.9081637367072684,-1.86228807 ...
