// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0-preview.4"
#r "nuget: Plotly.NET.Interactive, 2.0.0-preview.4"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="bde3cbe3-271b-4090-b28e-15b23a69dc9e" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_bde3cbe3271b4090b28e15b23a69dc9e = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[0.3422071899735517,-1.3192275729740357,-1.371465058020849,-0.8805454578247054,-0.8811041620688279,-0.7587739327446337,-0.9510784100076279,-0.18112642465998907,0.4626338990331942,-0.5488864919731105,-0.28722114701969825,-2.0034852154019998,-2.159895732235857,-1.6875876665927074,-0.4445318111582113,-1.4266354595962358,-1.3701619190751975,-1.1348784599224244,-1.186617315749705,-0.6211906155669504,-0.18903165882483886,-2.3695281191921045,-0.4162949802481303,-1.804901938673932,-1.029122379833508,-0.6708411541627098,-1.1162582760965787,-0.9082469377045758,-1.9944177136888646,-1.1076932839961986,-1.1467054373073196,-0.8595874619392085,-0.37929629818808885,-0.9867553339668298,-2.173267573559674,-0.10672696502237855,-1.0977350382885624,-1.1483272232567818,-0.594881434172474,-1.4823051390893953,-1.0732988249840543,-0.7815358633480912,-0.5882658277061981,-0.3164361528203752,-1.7639987362511786,-0.5201461416206373,0.33308220350109063,-0.8627052323369506,-0.22205462128892517